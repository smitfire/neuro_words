# %%
import sys, Quandl,nltk, csv, urllib2, codecs, simplejson, decimal, string, json
import numpy as np
from pprint import pprint as pp
from nltk.corpus import movie_reviews
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from textblob import TextBlob
from pymongo import MongoClient
import pandas as pd
from operator import itemgetter
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
client = MongoClient()
db = client.dsbc
nw = db.neuro_words
nwfeq = db.nwfeq
nwfeq2 = db.nwfeq2

nw.delete_many({"$where":"this.content.length < 100"})
nw.delete_many({"$where":"typeof(this.content) != 'string'"})

contents = nw.find({},{"content":1, "_id":0})
content_vals = [i['content'] for i in contents]

len(content_vals)
with open('result.json') as data_file:    
    data = json.load(data_file)

# for rev in reviews:
#     hmm.save(rev)

# %%
nwfeq2.remove({})
for key, val in data.items():
#     if index == 10:
#         break
    bregion = key.split(" | ")[1]
    scale = key.split(" | ")[0]
    my_hash = {"bregion": bregion, "scale": scale, "co-occ_count": val}
    nwfeq2.save(my_hash)

# %%
cursor = nwfeq2.find({'scale': {"$ne" : "quest"}}).sort([("co-occ_count", -1)])
cursor = nwfeq2.find().sort([("co-occ_count", -1)])
# db.test.find({"number": {"$gt": 1}}).sort([("number", 1), ("date", -1)])
list(cursor)
# Out:
# [{u'_id': ObjectId('55678222ea6387acd094662d'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 62,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946727'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 48,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946759'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 30,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd09466b0'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 29,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09466c9'),
#   u'bregion': u'cingulate cortex',
#   u'co-occ_count': 27,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946631'),
#   u'bregion': u'parietal cortex',
#   u'co-occ_count': 27,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946591'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 27,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946735'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 21,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946659'),
#   u'bregion': u'anterior cingulate cortex',
#   u'co-occ_count': 20,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd094663e'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 19,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd094664e'),
#   u'bregion': u'orbitofrontal cortex',
#   u'co-occ_count': 15,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946623'),
#   u'bregion': u'suprachiasmatic nucleus',
#   u'co-occ_count': 15,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946747'),
#   u'bregion': u'posterior parietal cortex',
#   u'co-occ_count': 14,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946596'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 14,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09465d3'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 12,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946756'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 11,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd094670d'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 11,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd094670a'),
#   u'bregion': u'visual cortex',
#   u'co-occ_count': 11,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09466b5'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 11,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09465ad'),
#   u'bregion': u'visual cortex',
#   u'co-occ_count': 11,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09466ab'),
#   u'bregion': u'parietal cortex',
#   u'co-occ_count': 10,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd0946745'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 9,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd0946730'),
#   u'bregion': u'posterior cingulate',
#   u'co-occ_count': 9,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946699'),
#   u'bregion': u'corpus callosum',
#   u'co-occ_count': 9,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946757'),
#   u'bregion': u'temporal cortex',
#   u'co-occ_count': 8,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09466a6'),
#   u'bregion': u'parietal lobule',
#   u'co-occ_count': 8,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd094663c'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 8,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09465fb'),
#   u'bregion': u'parietal region',
#   u'co-occ_count': 8,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946749'),
#   u'bregion': u'insular cortex',
#   u'co-occ_count': 7,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd09466cb'),
#   u'bregion': u'hypothalamus',
#   u'co-occ_count': 7,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09466bf'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 7,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd094667d'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 7,
#   u'scale': u'motives'},
#  {u'_id': ObjectId('55678222ea6387acd09465b6'),
#   u'bregion': u'cingulate cortex',
#   u'co-occ_count': 7,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946760'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 6,
#   u'scale': u'recognition memory test'},
#  {u'_id': ObjectId('55678222ea6387acd0946732'),
#   u'bregion': u'ventral striatum',
#   u'co-occ_count': 6,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd09466ff'),
#   u'bregion': u'cingulate cortex',
#   u'co-occ_count': 6,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09466e5'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 6,
#   u'scale': u'recognition memory test'},
#  {u'_id': ObjectId('55678222ea6387acd09466e2'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 6,
#   u'scale': u'childhood trauma questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd09466b2'),
#   u'bregion': u'cerebral hemisphere',
#   u'co-occ_count': 6,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946692'),
#   u'bregion': u'ventromedial prefrontal cortex',
#   u'co-occ_count': 6,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd094668a'),
#   u'bregion': u'intraparietal sulcus',
#   u'co-occ_count': 6,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd094667c'),
#   u'bregion': u'parietal regions',
#   u'co-occ_count': 6,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946644'),
#   u'bregion': u'posterior cingulate cortex',
#   u'co-occ_count': 6,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946640'),
#   u'bregion': u'anterior cingulate cortex',
#   u'co-occ_count': 6,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09465e8'),
#   u'bregion': u'parietal lobule',
#   u'co-occ_count': 6,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09465e1'),
#   u'bregion': u'motor cortex',
#   u'co-occ_count': 6,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09465c8'),
#   u'bregion': u'parietal cortices',
#   u'co-occ_count': 6,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09465c5'),
#   u'bregion': u'cuneus',
#   u'co-occ_count': 6,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09465bd'),
#   u'bregion': u'cuneus',
#   u'co-occ_count': 6,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09465ab'),
#   u'bregion': u'premotor cortex',
#   u'co-occ_count': 6,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09465a5'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 6,
#   u'scale': u'motives'},
#  {u'_id': ObjectId('55678222ea6387acd0946765'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 5,
#   u'scale': u'recognition memory test'},
#  {u'_id': ObjectId('55678222ea6387acd0946720'),
#   u'bregion': u'precuneus',
#   u'co-occ_count': 5,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09466ef'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 5,
#   u'scale': u'childhood trauma questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd09466dc'),
#   u'bregion': u'anterior cingulate cortex',
#   u'co-occ_count': 5,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09466d6'),
#   u'bregion': u'lateral orbitofrontal cortex',
#   u'co-occ_count': 5,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd09466a9'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 5,
#   u'scale': u'childhood trauma questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd094664f'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 5,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd094663f'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 5,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd0946605'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 5,
#   u'scale': u'spatial reasoning'},
#  {u'_id': ObjectId('55678222ea6387acd0946599'),
#   u'bregion': u'precuneus',
#   u'co-occ_count': 5,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd094658e'),
#   u'bregion': u'occipital cortex',
#   u'co-occ_count': 5,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd094675c'),
#   u'bregion': u'neocortex',
#   u'co-occ_count': 4,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd09466ca'),
#   u'bregion': u'orbitofrontal cortex',
#   u'co-occ_count': 4,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946642'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 4,
#   u'scale': u'childhood trauma questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd09466b3'),
#   u'bregion': u'posterior parietal cortex',
#   u'co-occ_count': 4,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd094669c'),
#   u'bregion': u'hypothalamus',
#   u'co-occ_count': 4,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946697'),
#   u'bregion': u'intraparietal sulcus',
#   u'co-occ_count': 4,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd0946690'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 4,
#   u'scale': u'spatial reasoning'},
#  {u'_id': ObjectId('55678222ea6387acd094668d'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 4,
#   u'scale': u'childhood trauma questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd0946685'),
#   u'bregion': u'cuneus',
#   u'co-occ_count': 4,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd094667f'),
#   u'bregion': u'limbic system',
#   u'co-occ_count': 4,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd094665f'),
#   u'bregion': u'temporal sulcus',
#   u'co-occ_count': 4,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946651'),
#   u'bregion': u'parietal lobule',
#   u'co-occ_count': 4,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd094663d'),
#   u'bregion': u'premotor cortex',
#   u'co-occ_count': 4,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd0946615'),
#   u'bregion': u'temporal cortex',
#   u'co-occ_count': 4,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09465d1'),
#   u'bregion': u'parietal cortex',
#   u'co-occ_count': 4,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd09465b1'),
#   u'bregion': u'temporal region',
#   u'co-occ_count': 4,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd094658c'),
#   u'bregion': u'motor cortex',
#   u'co-occ_count': 4,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd094675b'),
#   u'bregion': u'posterior cingulate',
#   u'co-occ_count': 3,
#   u'scale': u'motives'},
#  {u'_id': ObjectId('55678222ea6387acd0946753'),
#   u'bregion': u'frontal cortices',
#   u'co-occ_count': 3,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd094674a'),
#   u'bregion': u'somatosensory cortex',
#   u'co-occ_count': 3,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946740'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 3,
#   u'scale': u'aggression questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd094671a'),
#   u'bregion': u'neocortex',
#   u'co-occ_count': 3,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946713'),
#   u'bregion': u'subthalamic nucleus',
#   u'co-occ_count': 3,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946705'),
#   u'bregion': u'putamen',
#   u'co-occ_count': 3,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd09466f3'),
#   u'bregion': u'hypothalamus',
#   u'co-occ_count': 3,
#   u'scale': u'childhood trauma questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd09466e7'),
#   u'bregion': u'anterior cingulate cortex',
#   u'co-occ_count': 3,
#   u'scale': u'motives'},
#  {u'_id': ObjectId('55678222ea6387acd09466d2'),
#   u'bregion': u'ventromedial prefrontal cortex',
#   u'co-occ_count': 3,
#   u'scale': u'motives'},
#  {u'_id': ObjectId('55678222ea6387acd09466c8'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 3,
#   u'scale': u'childhood trauma questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd094669f'),
#   u'bregion': u'cerebrum',
#   u'co-occ_count': 3,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946694'),
#   u'bregion': u'frontal cortices',
#   u'co-occ_count': 3,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd094668f'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 3,
#   u'scale': u'recognition memory test'},
#  {u'_id': ObjectId('55678222ea6387acd094666e'),
#   u'bregion': u'cingulate cortex',
#   u'co-occ_count': 3,
#   u'scale': u'motives'},
#  {u'_id': ObjectId('55678222ea6387acd094665a'),
#   u'bregion': u'hypothalamus',
#   u'co-occ_count': 3,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd0946654'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 3,
#   u'scale': u'motives'},
#  {u'_id': ObjectId('55678222ea6387acd0946634'),
#   u'bregion': u'forebrain',
#   u'co-occ_count': 3,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946626'),
#   u'bregion': u'occipital sulcus',
#   u'co-occ_count': 3,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd094661e'),
#   u'bregion': u'somatosensory cortex',
#   u'co-occ_count': 3,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946612'),
#   u'bregion': u'cerebral cortex',
#   u'co-occ_count': 3,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946610'),
#   u'bregion': u'precuneus',
#   u'co-occ_count': 3,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946604'),
#   u'bregion': u'cerebral hemispheres',
#   u'co-occ_count': 3,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09465f8'),
#   u'bregion': u'posterior cingulate',
#   u'co-occ_count': 3,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09465f2'),
#   u'bregion': u'visual cortex',
#   u'co-occ_count': 3,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd09465f1'),
#   u'bregion': u'entorhinal cortex',
#   u'co-occ_count': 3,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09465de'),
#   u'bregion': u'hippocampal formation',
#   u'co-occ_count': 3,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09465db'),
#   u'bregion': u'temporal regions',
#   u'co-occ_count': 3,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09465bc'),
#   u'bregion': u'cerebral cortex',
#   u'co-occ_count': 3,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09465bb'),
#   u'bregion': u'temporal cortex',
#   u'co-occ_count': 3,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946767'),
#   u'bregion': u'orbitofrontal cortex',
#   u'co-occ_count': 2,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd0946751'),
#   u'bregion': u'corpus callosum',
#   u'co-occ_count': 2,
#   u'scale': u'childhood trauma questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd0946731'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 2,
#   u'scale': u'stress audit'},
#  {u'_id': ObjectId('55678222ea6387acd09466fc'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 2,
#   u'scale': u'personality assessment inventory'},
#  {u'_id': ObjectId('55678222ea6387acd0946728'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 2,
#   u'scale': u'personality assessment inventory'},
#  {u'_id': ObjectId('55678222ea6387acd0946704'),
#   u'bregion': u'forebrain',
#   u'co-occ_count': 2,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09466f7'),
#   u'bregion': u'occipital regions',
#   u'co-occ_count': 2,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd09466f1'),
#   u'bregion': u'parietal cortices',
#   u'co-occ_count': 2,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd09466ec'),
#   u'bregion': u'posterior cingulate cortex',
#   u'co-occ_count': 2,
#   u'scale': u'motives'},
#  {u'_id': ObjectId('55678222ea6387acd09466e3'),
#   u'bregion': u'cingulate regions',
#   u'co-occ_count': 2,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd09466d3'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 2,
#   u'scale': u'rorschach'},
#  {u'_id': ObjectId('55678222ea6387acd09466ce'),
#   u'bregion': u'temporal cortices',
#   u'co-occ_count': 2,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946679'),
#   u'bregion': u'parietal regions',
#   u'co-occ_count': 2,
#   u'scale': u'neuropsychological assessment battery'},
#  {u'_id': ObjectId('55678222ea6387acd09466c7'),
#   u'bregion': u'parietal cortices',
#   u'co-occ_count': 2,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd0946645'),
#   u'bregion': u'parietal region',
#   u'co-occ_count': 2,
#   u'scale': u'neuropsychological assessment battery'},
#  {u'_id': ObjectId('55678222ea6387acd09466be'),
#   u'bregion': u'temporal region',
#   u'co-occ_count': 2,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09466ba'),
#   u'bregion': u'limbic system',
#   u'co-occ_count': 2,
#   u'scale': u'stress audit'},
#  {u'_id': ObjectId('55678222ea6387acd0946639'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 2,
#   u'scale': u'neuropsychological assessment battery'},
#  {u'_id': ObjectId('55678222ea6387acd09466a0'),
#   u'bregion': u'entorhinal cortex',
#   u'co-occ_count': 2,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd094669b'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 2,
#   u'scale': u'aggression questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd0946698'),
#   u'bregion': u'septal region',
#   u'co-occ_count': 2,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946689'),
#   u'bregion': u'auditory cortex',
#   u'co-occ_count': 2,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd094667e'),
#   u'bregion': u'putamen',
#   u'co-occ_count': 2,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946678'),
#   u'bregion': u'primary visual cortex',
#   u'co-occ_count': 2,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946668'),
#   u'bregion': u'anterior cingulate cortices',
#   u'co-occ_count': 2,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946662'),
#   u'bregion': u'occipital regions',
#   u'co-occ_count': 2,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd094664c'),
#   u'bregion': u'occipital cortex',
#   u'co-occ_count': 2,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd094662f'),
#   u'bregion': u'temporal sulcus',
#   u'co-occ_count': 2,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd0946629'),
#   u'bregion': u'temporal region',
#   u'co-occ_count': 2,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946620'),
#   u'bregion': u'nucleus accumbens',
#   u'co-occ_count': 2,
#   u'scale': u'motives'},
#  {u'_id': ObjectId('55678222ea6387acd0946609'),
#   u'bregion': u'corpus callosum',
#   u'co-occ_count': 2,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd0946603'),
#   u'bregion': u'insular cortex',
#   u'co-occ_count': 2,
#   u'scale': u'motives'},
#  {u'_id': ObjectId('55678222ea6387acd0946601'),
#   u'bregion': u'posterior parietal cortex',
#   u'co-occ_count': 2,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd09465f6'),
#   u'bregion': u'cingulate region',
#   u'co-occ_count': 2,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd09465f5'),
#   u'bregion': u'temporal cortices',
#   u'co-occ_count': 2,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09465df'),
#   u'bregion': u'posterior cingulate cortex',
#   u'co-occ_count': 2,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09465dd'),
#   u'bregion': u'midbrain',
#   u'co-occ_count': 2,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd09465cf'),
#   u'bregion': u'posterior cingulate',
#   u'co-occ_count': 2,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09465cd'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 2,
#   u'scale': u'aggression questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd09465ca'),
#   u'bregion': u'occipital region',
#   u'co-occ_count': 2,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd09465b3'),
#   u'bregion': u'occipital region',
#   u'co-occ_count': 2,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09465b0'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 2,
#   u'scale': u'autobiographical memory interview'},
#  {u'_id': ObjectId('55678222ea6387acd09465a3'),
#   u'bregion': u'auditory cortex',
#   u'co-occ_count': 2,
#   u'scale': u'stress audit'},
#  {u'_id': ObjectId('55678222ea6387acd09465a0'),
#   u'bregion': u'occipital region',
#   u'co-occ_count': 2,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946597'),
#   u'bregion': u'cerebral cortex',
#   u'co-occ_count': 2,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd0946768'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'aggression questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd0946766'),
#   u'bregion': u'occipital cortices',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946764'),
#   u'bregion': u'ventromedial prefrontal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd094675e'),
#   u'bregion': u'entorhinal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'recognition memory test'},
#  {u'_id': ObjectId('55678222ea6387acd094675d'),
#   u'bregion': u'cingulate region',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946755'),
#   u'bregion': u'primary somatosensory cortex',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd0946754'),
#   u'bregion': u'parietal region',
#   u'co-occ_count': 1,
#   u'scale': u'severe impairment battery'},
#  {u'_id': ObjectId('55678222ea6387acd0946752'),
#   u'bregion': u'temporal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'clinical rating scale'},
#  {u'_id': ObjectId('55678222ea6387acd0946750'),
#   u'bregion': u'auditory cortex',
#   u'co-occ_count': 1,
#   u'scale': u'sensory profile'},
#  {u'_id': ObjectId('55678222ea6387acd094674f'),
#   u'bregion': u'ventral medial prefrontal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd094674e'),
#   u'bregion': u'insular cortices',
#   u'co-occ_count': 1,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd094674b'),
#   u'bregion': u'hypothalamus',
#   u'co-occ_count': 1,
#   u'scale': u'cognitive abilities test'},
#  {u'_id': ObjectId('55678222ea6387acd0946748'),
#   u'bregion': u'primary auditory cortex',
#   u'co-occ_count': 1,
#   u'scale': u'stress audit'},
#  {u'_id': ObjectId('55678222ea6387acd0946744'),
#   u'bregion': u'midbrain',
#   u'co-occ_count': 1,
#   u'scale': u'childhood trauma questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd0946743'),
#   u'bregion': u'cerebrum',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd094673f'),
#   u'bregion': u'putamen',
#   u'co-occ_count': 1,
#   u'scale': u'work performance assessment'},
#  {u'_id': ObjectId('55678222ea6387acd094673e'),
#   u'bregion': u'cingulate cortex',
#   u'co-occ_count': 1,
#   u'scale': u'childhood trauma questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd0946763'),
#   u'bregion': u'anterior cingulate cortex',
#   u'co-occ_count': 1,
#   u'scale': u'parent behavior checklist'},
#  {u'_id': ObjectId('55678222ea6387acd094675f'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'neuropsychological assessment battery'},
#  {u'_id': ObjectId('55678222ea6387acd0946738'),
#   u'bregion': u'temporal regions',
#   u'co-occ_count': 1,
#   u'scale': u'assessment evaluation'},
#  {u'_id': ObjectId('55678222ea6387acd0946737'),
#   u'bregion': u'corticotroph',
#   u'co-occ_count': 1,
#   u'scale': u'motives'},
#  {u'_id': ObjectId('55678222ea6387acd0946721'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'california computerized assessment package'},
#  {u'_id': ObjectId('55678222ea6387acd094672c'),
#   u'bregion': u'temporal region',
#   u'co-occ_count': 1,
#   u'scale': u'clinical rating scale'},
#  {u'_id': ObjectId('55678222ea6387acd094672a'),
#   u'bregion': u'hippocampal formation',
#   u'co-occ_count': 1,
#   u'scale': u'aggression questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd0946729'),
#   u'bregion': u'lenticular nucleus',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946725'),
#   u'bregion': u'intraparietal sulcus',
#   u'co-occ_count': 1,
#   u'scale': u'spatial reasoning'},
#  {u'_id': ObjectId('55678222ea6387acd0946724'),
#   u'bregion': u'cortical amygdala',
#   u'co-occ_count': 1,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd09466f8'),
#   u'bregion': u'orbitofrontal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'aberrant behavior checklist'},
#  {u'_id': ObjectId('55678222ea6387acd094671e'),
#   u'bregion': u'orbital cortex',
#   u'co-occ_count': 1,
#   u'scale': u'motives'},
#  {u'_id': ObjectId('55678222ea6387acd094671c'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'terranova'},
#  {u'_id': ObjectId('55678222ea6387acd094671b'),
#   u'bregion': u'secondary somatosensory cortices',
#   u'co-occ_count': 1,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946718'),
#   u'bregion': u'medial geniculate nucleus',
#   u'co-occ_count': 1,
#   u'scale': u'stress audit'},
#  {u'_id': ObjectId('55678222ea6387acd0946715'),
#   u'bregion': u'occipital region',
#   u'co-occ_count': 1,
#   u'scale': u'performance series'},
#  {u'_id': ObjectId('55678222ea6387acd0946714'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'general health questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd09466ee'),
#   u'bregion': u'ventromedial prefrontal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'personality assessment inventory'},
#  {u'_id': ObjectId('55678222ea6387acd094670c'),
#   u'bregion': u'occipital region',
#   u'co-occ_count': 1,
#   u'scale': u'childhood trauma questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd094670b'),
#   u'bregion': u'parietal region',
#   u'co-occ_count': 1,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946708'),
#   u'bregion': u'forebrain',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946707'),
#   u'bregion': u'intraparietal sulcus',
#   u'co-occ_count': 1,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946701'),
#   u'bregion': u'primary visual cortex',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09466fe'),
#   u'bregion': u'occipital cortex',
#   u'co-occ_count': 1,
#   u'scale': u'spatial reasoning'},
#  {u'_id': ObjectId('55678222ea6387acd09466fd'),
#   u'bregion': u'premotor cortex',
#   u'co-occ_count': 1,
#   u'scale': u'assessment evaluation'},
#  {u'_id': ObjectId('55678222ea6387acd09466fb'),
#   u'bregion': u'striate cortex',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09466f6'),
#   u'bregion': u'sensorimotor cortex',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09466f5'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 1,
#   u'scale': u'maslach burnout inventory'},
#  {u'_id': ObjectId('55678222ea6387acd09466f4'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'aberrant behavior checklist'},
#  {u'_id': ObjectId('55678222ea6387acd09466f2'),
#   u'bregion': u'frontal cortices',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09466f0'),
#   u'bregion': u'orbitofrontal region',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09466ed'),
#   u'bregion': u'habenula',
#   u'co-occ_count': 1,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd09466ea'),
#   u'bregion': u'temporal lobe',
#   u'co-occ_count': 1,
#   u'scale': u'american occupational therapy association'},
#  {u'_id': ObjectId('55678222ea6387acd09466e8'),
#   u'bregion': u'habenula',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09466e4'),
#   u'bregion': u'parietal region',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09466e0'),
#   u'bregion': u'corpus callosum',
#   u'co-occ_count': 1,
#   u'scale': u'severe impairment battery'},
#  {u'_id': ObjectId('55678222ea6387acd09466df'),
#   u'bregion': u'caudate nucleus',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09466db'),
#   u'bregion': u'parietal region',
#   u'co-occ_count': 1,
#   u'scale': u'performance series'},
#  {u'_id': ObjectId('55678222ea6387acd09466d8'),
#   u'bregion': u'parietal regions',
#   u'co-occ_count': 1,
#   u'scale': u'spatial reasoning'},
#  {u'_id': ObjectId('55678222ea6387acd09466d5'),
#   u'bregion': u'parietal regions',
#   u'co-occ_count': 1,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd09466d1'),
#   u'bregion': u'posterior cingulate cortices',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09466d0'),
#   u'bregion': u'nucleus accumbens',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09466cf'),
#   u'bregion': u'parietal regions',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09466cd'),
#   u'bregion': u'anterior thalamic nuclei',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09466cc'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'terranova'},
#  {u'_id': ObjectId('55678222ea6387acd09466ad'),
#   u'bregion': u'anterior cingulate cortex',
#   u'co-occ_count': 1,
#   u'scale': u'aggression questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd09466c5'),
#   u'bregion': u'cuneus',
#   u'co-occ_count': 1,
#   u'scale': u'motives'},
#  {u'_id': ObjectId('55678222ea6387acd09466c2'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 1,
#   u'scale': u'spatial reasoning'},
#  {u'_id': ObjectId('55678222ea6387acd09466c1'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 1,
#   u'scale': u'spatial reasoning'},
#  {u'_id': ObjectId('55678222ea6387acd09466c0'),
#   u'bregion': u'temporal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'spatial reasoning'},
#  {u'_id': ObjectId('55678222ea6387acd0946656'),
#   u'bregion': u'orbitofrontal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'childhood trauma questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd09466bc'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 1,
#   u'scale': u'benchmarks'},
#  {u'_id': ObjectId('55678222ea6387acd09466b9'),
#   u'bregion': u'hippocampal formation',
#   u'co-occ_count': 1,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd09466b8'),
#   u'bregion': u'frontal cortices',
#   u'co-occ_count': 1,
#   u'scale': u'rorschach'},
#  {u'_id': ObjectId('55678222ea6387acd09466b6'),
#   u'bregion': u'somatosensory cortex',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09466b4'),
#   u'bregion': u'subiculum',
#   u'co-occ_count': 1,
#   u'scale': u'childhood trauma questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd09466b1'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 1,
#   u'scale': u'neuropsychological assessment battery'},
#  {u'_id': ObjectId('55678222ea6387acd09466af'),
#   u'bregion': u'hippocampal formation',
#   u'co-occ_count': 1,
#   u'scale': u'derogatis stress profile'},
#  {u'_id': ObjectId('55678222ea6387acd09466ae'),
#   u'bregion': u'hippocampal formation',
#   u'co-occ_count': 1,
#   u'scale': u'stress profile'},
#  {u'_id': ObjectId('55678222ea6387acd09466a8'),
#   u'bregion': u'subthalamic nucleus',
#   u'co-occ_count': 1,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd09466a5'),
#   u'bregion': u'parietal region',
#   u'co-occ_count': 1,
#   u'scale': u'spatial reasoning'},
#  {u'_id': ObjectId('55678222ea6387acd0946638'),
#   u'bregion': u'orbitofrontal region',
#   u'co-occ_count': 1,
#   u'scale': u'childhood trauma questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd09466a3'),
#   u'bregion': u'parietal regions',
#   u'co-occ_count': 1,
#   u'scale': u'severe impairment battery'},
#  {u'_id': ObjectId('55678222ea6387acd09466a2'),
#   u'bregion': u'parietal regions',
#   u'co-occ_count': 1,
#   u'scale': u'assessment evaluation'},
#  {u'_id': ObjectId('55678222ea6387acd094669a'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'rorschach'},
#  {u'_id': ObjectId('55678222ea6387acd0946696'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 1,
#   u'scale': u'derogatis stress profile'},
#  {u'_id': ObjectId('55678222ea6387acd0946695'),
#   u'bregion': u'parietal region',
#   u'co-occ_count': 1,
#   u'scale': u'assessment evaluation'},
#  {u'_id': ObjectId('55678222ea6387acd0946693'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 1,
#   u'scale': u'stress profile'},
#  {u'_id': ObjectId('55678222ea6387acd094668e'),
#   u'bregion': u'putamen',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd094668c'),
#   u'bregion': u'allocortex',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd094662e'),
#   u'bregion': u'temporal cortices',
#   u'co-occ_count': 1,
#   u'scale': u'neuropsychological assessment battery'},
#  {u'_id': ObjectId('55678222ea6387acd0946681'),
#   u'bregion': u'presubiculum',
#   u'co-occ_count': 1,
#   u'scale': u'childhood trauma questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd0946680'),
#   u'bregion': u'claustrum',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd094667a'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'assessment evaluation'},
#  {u'_id': ObjectId('55678222ea6387acd0946676'),
#   u'bregion': u'lateral geniculate nucleus',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd0946674'),
#   u'bregion': u'temporal regions',
#   u'co-occ_count': 1,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946673'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 1,
#   u'scale': u'aggression questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd0946672'),
#   u'bregion': u'ventral medial prefrontal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd094666f'),
#   u'bregion': u'temporal lobe',
#   u'co-occ_count': 1,
#   u'scale': u'multilingual aphasia examination'},
#  {u'_id': ObjectId('55678222ea6387acd094666b'),
#   u'bregion': u'orbitofrontal cortices',
#   u'co-occ_count': 1,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946666'),
#   u'bregion': u'auditory cortex',
#   u'co-occ_count': 1,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946665'),
#   u'bregion': u'occipital region',
#   u'co-occ_count': 1,
#   u'scale': u'spatial reasoning'},
#  {u'_id': ObjectId('55678222ea6387acd0946661'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 1,
#   u'scale': u'stress audit'},
#  {u'_id': ObjectId('55678222ea6387acd094665e'),
#   u'bregion': u'putamen',
#   u'co-occ_count': 1,
#   u'scale': u'childhood trauma questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd094665d'),
#   u'bregion': u'cingulate regions',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd094665c'),
#   u'bregion': u'occipital cortex',
#   u'co-occ_count': 1,
#   u'scale': u'motives'},
#  {u'_id': ObjectId('55678222ea6387acd094665b'),
#   u'bregion': u'temporal regions',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd0946658'),
#   u'bregion': u'occipital cortex',
#   u'co-occ_count': 1,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd094662b'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'california computerized assessment package'},
#  {u'_id': ObjectId('55678222ea6387acd0946649'),
#   u'bregion': u'primary somatosensory cortex',
#   u'co-occ_count': 1,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946648'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 1,
#   u'scale': u'aberrant behavior checklist'},
#  {u'_id': ObjectId('55678222ea6387acd0946647'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 1,
#   u'scale': u'rorschach'},
#  {u'_id': ObjectId('55678222ea6387acd0946646'),
#   u'bregion': u'extrastriate cortex',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd0946643'),
#   u'bregion': u'orbitofrontal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'motives'},
#  {u'_id': ObjectId('55678222ea6387acd094663b'),
#   u'bregion': u'geniculate nucleus',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd094663a'),
#   u'bregion': u'parietal cortices',
#   u'co-occ_count': 1,
#   u'scale': u'spatial reasoning'},
#  {u'_id': ObjectId('55678222ea6387acd0946637'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 1,
#   u'scale': u'vineland adaptive behavior scales'},
#  {u'_id': ObjectId('55678222ea6387acd0946632'),
#   u'bregion': u'insular cortex',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946630'),
#   u'bregion': u'thalamic nuclei',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd094662a'),
#   u'bregion': u'anterior cingulate cortex',
#   u'co-occ_count': 1,
#   u'scale': u'childhood trauma questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd0946627'),
#   u'bregion': u'nucleus accumbens',
#   u'co-occ_count': 1,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946625'),
#   u'bregion': u'cerebrum',
#   u'co-occ_count': 1,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946624'),
#   u'bregion': u'temporal region',
#   u'co-occ_count': 1,
#   u'scale': u'assessment evaluation'},
#  {u'_id': ObjectId('55678222ea6387acd094661f'),
#   u'bregion': u'frontal cortices',
#   u'co-occ_count': 1,
#   u'scale': u'aggression questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd094661b'),
#   u'bregion': u'hypophysis',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946619'),
#   u'bregion': u'hypothalamus',
#   u'co-occ_count': 1,
#   u'scale': u'rorschach'},
#  {u'_id': ObjectId('55678222ea6387acd0946613'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'general health questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd094660e'),
#   u'bregion': u'mesencephalon',
#   u'co-occ_count': 1,
#   u'scale': u'stress audit'},
#  {u'_id': ObjectId('55678222ea6387acd094660d'),
#   u'bregion': u'hippocampal formation',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd094660c'),
#   u'bregion': u'subiculum',
#   u'co-occ_count': 1,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd094660b'),
#   u'bregion': u'precuneus',
#   u'co-occ_count': 1,
#   u'scale': u'motives'},
#  {u'_id': ObjectId('55678222ea6387acd094660a'),
#   u'bregion': u'hypothalamus',
#   u'co-occ_count': 1,
#   u'scale': u'composite international diagnostic interview'},
#  {u'_id': ObjectId('55678222ea6387acd0946608'),
#   u'bregion': u'primary somatosensory cortex',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd0946607'),
#   u'bregion': u'motor cortex',
#   u'co-occ_count': 1,
#   u'scale': u'assessment evaluation'},
#  {u'_id': ObjectId('55678222ea6387acd09465e3'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 1,
#   u'scale': u'composite international diagnostic interview'},
#  {u'_id': ObjectId('55678222ea6387acd0946606'),
#   u'bregion': u'central amygdala',
#   u'co-occ_count': 1,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd0946600'),
#   u'bregion': u'motor cortex',
#   u'co-occ_count': 1,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd09465fe'),
#   u'bregion': u'corpus callosum',
#   u'co-occ_count': 1,
#   u'scale': u'spatial reasoning'},
#  {u'_id': ObjectId('55678222ea6387acd09465d7'),
#   u'bregion': u'corpus callosum',
#   u'co-occ_count': 1,
#   u'scale': u'antisocial process screening device'},
#  {u'_id': ObjectId('55678222ea6387acd09465c6'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'neuropsychological assessment battery'},
#  {u'_id': ObjectId('55678222ea6387acd09465fa'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 1,
#   u'scale': u'work performance assessment'},
#  {u'_id': ObjectId('55678222ea6387acd09465f4'),
#   u'bregion': u'cerebral cortices',
#   u'co-occ_count': 1,
#   u'scale': u'feelings'},
#  {u'_id': ObjectId('55678222ea6387acd09465f3'),
#   u'bregion': u'parietal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'recognition memory test'},
#  {u'_id': ObjectId('55678222ea6387acd09465f0'),
#   u'bregion': u'cerebral aqueduct',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09465eb'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09465ea'),
#   u'bregion': u'temporal regions',
#   u'co-occ_count': 1,
#   u'scale': u'metaphon'},
#  {u'_id': ObjectId('55678222ea6387acd09465e9'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 1,
#   u'scale': u'parent behavior checklist'},
#  {u'_id': ObjectId('55678222ea6387acd09465e7'),
#   u'bregion': u'visual cortex',
#   u'co-occ_count': 1,
#   u'scale': u'recognition memory test'},
#  {u'_id': ObjectId('55678222ea6387acd09465e6'),
#   u'bregion': u'internal capsule',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09465e4'),
#   u'bregion': u'extrastriate cortex',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09465e0'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 1,
#   u'scale': u'cognitive abilities test'},
#  {u'_id': ObjectId('55678222ea6387acd09465da'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 1,
#   u'scale': u'personality assessment inventory'},
#  {u'_id': ObjectId('55678222ea6387acd09465d9'),
#   u'bregion': u'midbrain',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09465d5'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'assessment evaluation'},
#  {u'_id': ObjectId('55678222ea6387acd09465c2'),
#   u'bregion': u'occipital regions',
#   u'co-occ_count': 1,
#   u'scale': u'childhood trauma questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd09465d4'),
#   u'bregion': u'orbitofrontal regions',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09465d2'),
#   u'bregion': u'cingulate cortex',
#   u'co-occ_count': 1,
#   u'scale': u'parent behavior checklist'},
#  {u'_id': ObjectId('55678222ea6387acd09465ce'),
#   u'bregion': u'anterior parietal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09465cc'),
#   u'bregion': u'cingulate cortex',
#   u'co-occ_count': 1,
#   u'scale': u'aggression questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd09465cb'),
#   u'bregion': u'caudate nucleus',
#   u'co-occ_count': 1,
#   u'scale': u'aberrant behavior checklist'},
#  {u'_id': ObjectId('55678222ea6387acd09465c9'),
#   u'bregion': u'geniculate nucleus',
#   u'co-occ_count': 1,
#   u'scale': u'stress audit'},
#  {u'_id': ObjectId('55678222ea6387acd09465c4'),
#   u'bregion': u'temporal region',
#   u'co-occ_count': 1,
#   u'scale': u'metaphon'},
#  {u'_id': ObjectId('55678222ea6387acd09465c3'),
#   u'bregion': u'frontal sulcus',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09465c1'),
#   u'bregion': u'hypothalamus',
#   u'co-occ_count': 1,
#   u'scale': u'stress audit'},
#  {u'_id': ObjectId('55678222ea6387acd09465c0'),
#   u'bregion': u'striate cortex',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09465be'),
#   u'bregion': u'entorhinal cortices',
#   u'co-occ_count': 1,
#   u'scale': u'recognition memory test'},
#  {u'_id': ObjectId('55678222ea6387acd09465b9'),
#   u'bregion': u'subthalamic nucleus',
#   u'co-occ_count': 1,
#   u'scale': u'rorschach'},
#  {u'_id': ObjectId('55678222ea6387acd09465b5'),
#   u'bregion': u'posterior cingulate cortex',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09465b2'),
#   u'bregion': u'hypothalamus',
#   u'co-occ_count': 1,
#   u'scale': u'maslach burnout inventory'},
#  {u'_id': ObjectId('55678222ea6387acd09465af'),
#   u'bregion': u'temporal regions',
#   u'co-occ_count': 1,
#   u'scale': u'interpersonal adjective scales'},
#  {u'_id': ObjectId('55678222ea6387acd09465ae'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'clinical rating scale'},
#  {u'_id': ObjectId('55678222ea6387acd09465aa'),
#   u'bregion': u'limbic system',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09465a7'),
#   u'bregion': u'globus pallidus',
#   u'co-occ_count': 1,
#   u'scale': u'viewpoint'},
#  {u'_id': ObjectId('55678222ea6387acd09465a6'),
#   u'bregion': u'septum pellucidum',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09465a4'),
#   u'bregion': u'temporal region',
#   u'co-occ_count': 1,
#   u'scale': u'interpersonal adjective scales'},
#  {u'_id': ObjectId('55678222ea6387acd094659f'),
#   u'bregion': u'neocortices',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd094659d'),
#   u'bregion': u'ventral striatum',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd094659a'),
#   u'bregion': u'temporal cortex',
#   u'co-occ_count': 1,
#   u'scale': u'listening comprehension'},
#  {u'_id': ObjectId('55678222ea6387acd0946598'),
#   u'bregion': u'corticotroph',
#   u'co-occ_count': 1,
#   u'scale': u'maslach burnout inventory'},
#  {u'_id': ObjectId('55678222ea6387acd0946595'),
#   u'bregion': u'corticotroph',
#   u'co-occ_count': 1,
#   u'scale': u'pace'},
#  {u'_id': ObjectId('55678222ea6387acd09465ba'),
#   u'bregion': u'anterior cingulate cortices',
#   u'co-occ_count': 1,
#   u'scale': u'aggression questionnaire'},
#  {u'_id': ObjectId('55678222ea6387acd09465b7'),
#   u'bregion': u'internal capsule',
#   u'co-occ_count': 1,
#   u'scale': u'composite international diagnostic interview'},
#  {u'_id': ObjectId('55678222ea6387acd094658d'),
#   u'bregion': u'caudate nucleus',
#   u'co-occ_count': 1,
#   u'scale': u'pace'}]

# %%
cursor_grouped = nwfeq2.aggregate(
   [
     { "$group" : { "_id" : "$co-occur_count", "nwfeq2": { "$push": "$scale" } } }
   ]
)
list(cursor_grouped)
# Out:
# [{u'_id': None,
#   u'nwfeq2': [u'viewpoint',
#    u'pace',
#    u'viewpoint',
#    u'quest',
#    u'quest',
#    u'feelings',
#    u'quest',
#    u'quest',
#    u'quest',
#    u'pace',
#    u'pace',
#    u'viewpoint',
#    u'maslach burnout inventory',
#    u'viewpoint',
#    u'listening comprehension',
#    u'quest',
#    u'quest',
#    u'pace',
#    u'quest',
#    u'pace',
#    u'pace',
#    u'quest',
#    u'quest',
#    u'stress audit',
#    u'interpersonal adjective scales',
#    u'motives',
#    u'pace',
#    u'viewpoint',
#    u'quest',
#    u'quest',
#    u'viewpoint',
#    u'pace',
#    u'quest',
#    u'viewpoint',
#    u'clinical rating scale',
#    u'interpersonal adjective scales',
#    u'autobiographical memory interview',
#    u'pace',
#    u'maslach burnout inventory',
#    u'viewpoint',
#    u'quest',
#    u'viewpoint',
#    u'pace',
#    u'composite international diagnostic interview',
#    u'quest',
#    u'rorschach',
#    u'aggression questionnaire',
#    u'feelings',
#    u'pace',
#    u'viewpoint',
#    u'recognition memory test',
#    u'quest',
#    u'pace',
#    u'stress audit',
#    u'childhood trauma questionnaire',
#    u'pace',
#    u'metaphon',
#    u'pace',
#    u'neuropsychological assessment battery',
#    u'quest',
#    u'pace',
#    u'stress audit',
#    u'feelings',
#    u'aberrant behavior checklist',
#    u'aggression questionnaire',
#    u'aggression questionnaire',
#    u'viewpoint',
#    u'viewpoint',
#    u'quest',
#    u'feelings',
#    u'parent behavior checklist',
#    u'feelings',
#    u'viewpoint',
#    u'assessment evaluation',
#    u'quest',
#    u'antisocial process screening device',
#    u'quest',
#    u'pace',
#    u'personality assessment inventory',
#    u'pace',
#    u'quest',
#    u'feelings',
#    u'viewpoint',
#    u'pace',
#    u'cognitive abilities test',
#    u'pace',
#    u'quest',
#    u'composite international diagnostic interview',
#    u'pace',
#    u'quest',
#    u'pace',
#    u'recognition memory test',
#    u'viewpoint',
#    u'parent behavior checklist',
#    u'metaphon',
#    u'viewpoint',
#    u'quest',
#    u'quest',
#    u'quest',
#    u'quest',
#    u'pace',
#    u'pace',
#    u'feelings',
#    u'recognition memory test',
#    u'feelings',
#    u'pace',
#    u'feelings',
#    u'quest',
#    u'pace',
#    u'quest',
#    u'work performance assessment',
#    u'pace',
#    u'quest',
#    u'quest',
#    u'spatial reasoning',
#    u'quest',
#    u'feelings',
#    u'feelings',
#    u'quest',
#    u'motives',
#    u'pace',
#    u'spatial reasoning',
#    u'feelings',
#    u'assessment evaluation',
#    u'pace',
#    u'viewpoint',
#    u'composite international diagnostic interview',
#    u'motives',
#    u'feelings',
#    u'pace',
#    u'stress audit',
#    u'quest',
#    u'feelings',
#    u'quest',
#    u'feelings',
#    u'general health questionnaire',
#    u'quest',
#    u'pace',
#    u'quest',
#    u'quest',
#    u'quest',
#    u'rorschach',
#    u'quest',
#    u'pace',
#    u'quest',
#    u'quest',
#    u'feelings',
#    u'aggression questionnaire',
#    u'motives',
#    u'quest',
#    u'quest',
#    u'pace',
#    u'assessment evaluation',
#    u'feelings',
#    u'viewpoint',
#    u'feelings',
#    u'quest',
#    u'feelings',
#    u'childhood trauma questionnaire',
#    u'california computerized assessment package',
#    u'quest',
#    u'feelings',
#    u'neuropsychological assessment battery',
#    u'viewpoint',
#    u'viewpoint',
#    u'pace',
#    u'pace',
#    u'quest',
#    u'feelings',
#    u'quest',
#    u'quest',
#    u'vineland adaptive behavior scales',
#    u'childhood trauma questionnaire',
#    u'neuropsychological assessment battery',
#    u'spatial reasoning',
#    u'viewpoint',
#    u'pace',
#    u'viewpoint',
#    u'pace',
#    u'viewpoint',
#    u'viewpoint',
#    u'quest',
#    u'childhood trauma questionnaire',
#    u'motives',
#    u'feelings',
#    u'neuropsychological assessment battery',
#    u'viewpoint',
#    u'rorschach',
#    u'aberrant behavior checklist',
#    u'feelings',
#    u'quest',
#    u'quest',
#    u'pace',
#    u'quest',
#    u'feelings',
#    u'pace',
#    u'quest',
#    u'feelings',
#    u'quest',
#    u'quest',
#    u'motives',
#    u'quest',
#    u'childhood trauma questionnaire',
#    u'quest',
#    u'feelings',
#    u'feelings',
#    u'viewpoint',
#    u'viewpoint',
#    u'motives',
#    u'pace',
#    u'childhood trauma questionnaire',
#    u'feelings',
#    u'quest',
#    u'stress audit',
#    u'pace',
#    u'quest',
#    u'quest',
#    u'spatial reasoning',
#    u'feelings',
#    u'quest',
#    u'feelings',
#    u'quest',
#    u'quest',
#    u'feelings',
#    u'quest',
#    u'quest',
#    u'motives',
#    u'multilingual aphasia examination',
#    u'quest',
#    u'quest',
#    u'pace',
#    u'aggression questionnaire',
#    u'feelings',
#    u'quest',
#    u'viewpoint',
#    u'quest',
#    u'pace',
#    u'neuropsychological assessment battery',
#    u'assessment evaluation',
#    u'quest',
#    u'pace',
#    u'motives',
#    u'pace',
#    u'feelings',
#    u'pace',
#    u'childhood trauma questionnaire',
#    u'quest',
#    u'quest',
#    u'quest',
#    u'feelings',
#    u'quest',
#    u'quest',
#    u'quest',
#    u'pace',
#    u'pace',
#    u'quest',
#    u'pace',
#    u'childhood trauma questionnaire',
#    u'viewpoint',
#    u'recognition memory test',
#    u'spatial reasoning',
#    u'quest',
#    u'feelings',
#    u'stress profile',
#    u'feelings',
#    u'assessment evaluation',
#    u'derogatis stress profile',
#    u'viewpoint',
#    u'feelings',
#    u'pace',
#    u'rorschach',
#    u'aggression questionnaire',
#    u'feelings',
#    u'quest',
#    u'quest',
#    u'pace',
#    u'feelings',
#    u'quest',
#    u'assessment evaluation',
#    u'severe impairment battery',
#    u'quest',
#    u'spatial reasoning',
#    u'pace',
#    u'quest',
#    u'feelings',
#    u'childhood trauma questionnaire',
#    u'quest',
#    u'viewpoint',
#    u'quest',
#    u'aggression questionnaire',
#    u'stress profile',
#    u'derogatis stress profile',
#    u'pace',
#    u'neuropsychological assessment battery',
#    u'pace',
#    u'viewpoint',
#    u'childhood trauma questionnaire',
#    u'viewpoint',
#    u'viewpoint',
#    u'quest',
#    u'rorschach',
#    u'feelings',
#    u'stress audit',
#    u'quest',
#    u'benchmarks',
#    u'quest',
#    u'viewpoint',
#    u'viewpoint',
#    u'spatial reasoning',
#    u'spatial reasoning',
#    u'spatial reasoning',
#    u'quest',
#    u'quest',
#    u'motives',
#    u'quest',
#    u'viewpoint',
#    u'childhood trauma questionnaire',
#    u'feelings',
#    u'pace',
#    u'pace',
#    u'terranova',
#    u'viewpoint',
#    u'feelings',
#    u'viewpoint',
#    u'pace',
#    u'pace',
#    u'motives',
#    u'rorschach',
#    u'quest',
#    u'feelings',
#    u'feelings',
#    u'quest',
#    u'spatial reasoning',
#    u'quest',
#    u'quest',
#    u'performance series',
#    u'pace',
#    u'quest',
#    u'quest',
#    u'viewpoint',
#    u'severe impairment battery',
#    u'quest',
#    u'childhood trauma questionnaire',
#    u'feelings',
#    u'viewpoint',
#    u'recognition memory test',
#    u'quest',
#    u'motives',
#    u'pace',
#    u'quest',
#    u'american occupational therapy association',
#    u'quest',
#    u'motives',
#    u'feelings',
#    u'personality assessment inventory',
#    u'childhood trauma questionnaire',
#    u'viewpoint',
#    u'feelings',
#    u'viewpoint',
#    u'childhood trauma questionnaire',
#    u'aberrant behavior checklist',
#    u'maslach burnout inventory',
#    u'pace',
#    u'feelings',
#    u'aberrant behavior checklist',
#    u'quest',
#    u'quest',
#    u'viewpoint',
#    u'personality assessment inventory',
#    u'assessment evaluation',
#    u'spatial reasoning',
#    u'viewpoint',
#    u'quest',
#    u'viewpoint',
#    u'quest',
#    u'quest',
#    u'viewpoint',
#    u'feelings',
#    u'quest',
#    u'feelings',
#    u'pace',
#    u'quest',
#    u'pace',
#    u'feelings',
#    u'childhood trauma questionnaire',
#    u'viewpoint',
#    u'quest',
#    u'quest',
#    u'quest',
#    u'quest',
#    u'quest',
#    u'pace',
#    u'general health questionnaire',
#    u'performance series',
#    u'quest',
#    u'quest',
#    u'stress audit',
#    u'quest',
#    u'pace',
#    u'feelings',
#    u'terranova',
#    u'quest',
#    u'motives',
#    u'quest',
#    u'pace',
#    u'california computerized assessment package',
#    u'quest',
#    u'quest',
#    u'feelings',
#    u'spatial reasoning',
#    u'quest',
#    u'feelings',
#    u'personality assessment inventory',
#    u'pace',
#    u'aggression questionnaire',
#    u'quest',
#    u'clinical rating scale',
#    u'quest',
#    u'quest',
#    u'quest',
#    u'feelings',
#    u'stress audit',
#    u'feelings',
#    u'quest',
#    u'quest',
#    u'pace',
#    u'quest',
#    u'motives',
#    u'assessment evaluation',
#    u'quest',
#    u'quest',
#    u'quest',
#    u'quest',
#    u'quest',
#    u'childhood trauma questionnaire',
#    u'work performance assessment',
#    u'aggression questionnaire',
#    u'quest',
#    u'quest',
#    u'viewpoint',
#    u'childhood trauma questionnaire',
#    u'viewpoint',
#    u'quest',
#    u'pace',
#    u'stress audit',
#    u'feelings',
#    u'pace',
#    u'cognitive abilities test',
#    u'quest',
#    u'quest',
#    u'feelings',
#    u'feelings',
#    u'sensory profile',
#    u'childhood trauma questionnaire',
#    u'clinical rating scale',
#    u'pace',
#    u'severe impairment battery',
#    u'viewpoint',
#    u'feelings',
#    u'viewpoint',
#    u'quest',
#    u'feelings',
#    u'quest',
#    u'motives',
#    u'feelings',
#    u'pace',
#    u'recognition memory test',
#    u'neuropsychological assessment battery',
#    u'recognition memory test',
#    u'quest',
#    u'quest',
#    u'parent behavior checklist',
#    u'pace',
#    u'recognition memory test',
#    u'pace',
#    u'viewpoint',
#    u'aggression questionnaire']}]

# %%
# vectorizer = TfidfVectorizer(stop_words="english", lowercase=False, encoding=u'utf-8')
# doc_vectors = vectorizer.fit_transform(content_vals)
# idf = vectorizer._tfidf.idf_
# idf_dic = dict(zip(vectorizer.get_feature_names(), idf))
# def format_brain(fname):
#     my_file = open(fname, "r")
#     read_file = my_file.read()
#     my_file.close()
#     return list(set(read_file.translate(string.maketrans("",""), string.punctuation).lower().split("\n")))

# def format_scale(fname):
#     my_file = open(fname, "r")
#     lines = list(set(my_file.read().split("\r")))
#     return [line.split(',')[0] for line in lines]

# bterms = format_brain("mesh_brain3.txt")
# sterms = format_scale("mmy_index.txt")

# %%
nw2 = db.neuro_words2
nw2.delete_many({"$where":"this.content.length < 100"})
nw2.delete_many({"$where":"typeof(this.content) != 'string'"})
thing = nw.find({},{"scales":1, "_id":0})
list(thing)
# Out:
# [{},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  ...]
