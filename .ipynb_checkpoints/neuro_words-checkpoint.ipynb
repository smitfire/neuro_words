# %%
import sys, Quandl,nltk, csv, urllib2, codecs, simplejson, decimal, string, json
import numpy as np
from pprint import pprint as pp
from nltk.corpus import movie_reviews
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from textblob import TextBlob
from pymongo import MongoClient
import pandas as pd
from operator import itemgetter
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
client = MongoClient()
db = client.dsbc
nw = db.neuro_words
nwfeq = db.nwfeq
nwfeq2 = db.nwfeq2
nwf = db.nwf

# nw.delete_many({"$where":"this.content.length < 100"})
# nw.delete_many({"$where":"typeof(this.content) != 'string'"})

# contents = nw.find({},{"content":1, "_id":0})
# content_vals = [i['content'] for i in contents]

# len(content_vals)
with open('result2.json') as data_file:    
    data = json.load(data_file)

# for rev in reviews:
#     hmm.save(rev)

# %%
nwfeq.remove({})
nwf.remove({})
nwfeq2.remove({})

for key, val in data.items():
#     if index == 10:
#         break
    bregion = key.split(" | ")[1]
    scale = key.split(" | ")[0]
    my_hash = {"bregion": bregion, "scale": scale, "co-occ_count": val}
    nwf.save(my_hash)

# %%
# cursor = nwfeq2.find({'scale': {"$ne" : "quest"}}).sort([("co-occ_count", -1)])
# cursor = nwf.find({"bregion":{"$ne" : ""}}, {"scale":{"$ne" : ""}}).sort([("co-occ_count", -1)])
# cursor = nwf.find({ "$and": [ { "scale": { "$ne": "" } }, { "bregion": { "$ne": "" } } ] }).sort([("co-occ_count", -1)])
cursor = nwf.find({ "$and": [ { "$where": "this.scale.length > 5" }, { "$where": "this.bregion.length > 5" } ] }).sort([("co-occ_count", -1)])

list(cursor)
# Out:
# [{u'_id': ObjectId('55683839ea6387de73a8aeaf'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 8598,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8c221'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 6428,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8c2de'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 6122,
#   u'scale': u'da'},
#  {u'_id': ObjectId('55683839ea6387de73a8a737'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 5829,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('55683839ea6387de73a8a648'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 5330,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383bea6387de73a8da02'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 4956,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383bea6387de73a8d824'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 4679,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383bea6387de73a8d37e'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 4609,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383bea6387de73a8c964'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 4567,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('55683839ea6387de73a8a56c'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 4328,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383bea6387de73a8da59'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 4302,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383aea6387de73a8c146'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 4173,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383bea6387de73a8c9eb'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 3918,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('55683839ea6387de73a8a5ae'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 3843,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383aea6387de73a8b43e'),
#   u'bregion': u'temporal lobe',
#   u'co-occ_count': 3645,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8be1d'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 3534,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383bea6387de73a8d062'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 3527,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383aea6387de73a8bffa'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 3430,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('55683839ea6387de73a8acb4'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 3412,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('55683839ea6387de73a8aa46'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 3216,
#   u'scale': u'da'},
#  {u'_id': ObjectId('55683839ea6387de73a8a8cc'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 3183,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383aea6387de73a8c1b7'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 3121,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383bea6387de73a8cf4d'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 3084,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('55683839ea6387de73a8aa23'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 3080,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383cea6387de73a8e015'),
#   u'bregion': u'temporal lobe',
#   u'co-occ_count': 3028,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('55683839ea6387de73a8a2b0'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 2946,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('5568383aea6387de73a8b63e'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 2858,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383aea6387de73a8bb05'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 2679,
#   u'scale': u'pal'},
#  {u'_id': ObjectId('5568383bea6387de73a8d4d4'),
#   u'bregion': u'temporal lobe',
#   u'co-occ_count': 2664,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383cea6387de73a8dc58'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 2636,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383bea6387de73a8d328'),
#   u'bregion': u'cingulate cortex',
#   u'co-occ_count': 2620,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('55683839ea6387de73a8a34b'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 2574,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383aea6387de73a8b6ec'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 2530,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383bea6387de73a8d3df'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 2407,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383bea6387de73a8ccd0'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 2363,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('55683839ea6387de73a8a8b0'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 2358,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('55683839ea6387de73a8acea'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 2268,
#   u'scale': u'pai'},
#  {u'_id': ObjectId('5568383bea6387de73a8cfd4'),
#   u'bregion': u'temporal lobe',
#   u'co-occ_count': 2251,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383aea6387de73a8c154'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 2221,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('5568383bea6387de73a8c8d8'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 2220,
#   u'scale': u'da'},
#  {u'_id': ObjectId('55683839ea6387de73a8ad14'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 2189,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('55683839ea6387de73a8a487'),
#   u'bregion': u'temporal lobe',
#   u'co-occ_count': 2162,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383aea6387de73a8b75c'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 1992,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383bea6387de73a8ceba'),
#   u'bregion': u'frontal lobe',
#   u'co-occ_count': 1989,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383bea6387de73a8ca65'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 1971,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b9cc'),
#   u'bregion': u'motor cortex',
#   u'co-occ_count': 1898,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8bdf8'),
#   u'bregion': u'cingulate cortex',
#   u'co-occ_count': 1898,
#   u'scale': u'da'},
#  {u'_id': ObjectId('55683839ea6387de73a8ac71'),
#   u'bregion': u'temporal lobe',
#   u'co-occ_count': 1895,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383aea6387de73a8c2be'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 1880,
#   u'scale': u'da'},
#  {u'_id': ObjectId('55683839ea6387de73a8a55b'),
#   u'bregion': u'cingulate cortex',
#   u'co-occ_count': 1854,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383bea6387de73a8d722'),
#   u'bregion': u'temporal lobe',
#   u'co-occ_count': 1847,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383bea6387de73a8cddc'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 1842,
#   u'scale': u'cri'},
#  {u'_id': ObjectId('5568383cea6387de73a8dfc5'),
#   u'bregion': u'parietal cortex',
#   u'co-occ_count': 1831,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8b706'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 1828,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('55683839ea6387de73a8ae1e'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 1827,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b351'),
#   u'bregion': u'anterior cingulate cortex',
#   u'co-occ_count': 1826,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8c0ca'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 1819,
#   u'scale': u'pai'},
#  {u'_id': ObjectId('55683839ea6387de73a8ab80'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 1804,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('55683839ea6387de73a8a8a6'),
#   u'bregion': u'temporal lobe',
#   u'co-occ_count': 1776,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383aea6387de73a8bba1'),
#   u'bregion': u'basal ganglia',
#   u'co-occ_count': 1734,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8b011'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 1723,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383bea6387de73a8d1a8'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 1687,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383bea6387de73a8d8d3'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 1683,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383bea6387de73a8d83d'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 1669,
#   u'scale': u'pai'},
#  {u'_id': ObjectId('5568383bea6387de73a8d0f7'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 1661,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383aea6387de73a8bb38'),
#   u'bregion': u'cingulate cortex',
#   u'co-occ_count': 1657,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('55683839ea6387de73a8acd4'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 1613,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383bea6387de73a8ca41'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 1601,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383bea6387de73a8d15e'),
#   u'bregion': u'frontal lobe',
#   u'co-occ_count': 1551,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383bea6387de73a8c941'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 1543,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383bea6387de73a8c8e6'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 1516,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383bea6387de73a8ca51'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 1457,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b7c5'),
#   u'bregion': u'cingulate cortex',
#   u'co-occ_count': 1443,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('55683839ea6387de73a8a247'),
#   u'bregion': u'basal ganglia',
#   u'co-occ_count': 1442,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b5df'),
#   u'bregion': u'cingulate cortex',
#   u'co-occ_count': 1440,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('55683839ea6387de73a8ab95'),
#   u'bregion': u'temporal lobe',
#   u'co-occ_count': 1434,
#   u'scale': u'pai'},
#  {u'_id': ObjectId('5568383aea6387de73a8bbfc'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 1395,
#   u'scale': u'cri'},
#  {u'_id': ObjectId('5568383aea6387de73a8b093'),
#   u'bregion': u'frontal lobe',
#   u'co-occ_count': 1382,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383cea6387de73a8dd68'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 1379,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383cea6387de73a8e08a'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 1374,
#   u'scale': u'cri'},
#  {u'_id': ObjectId('5568383bea6387de73a8d170'),
#   u'bregion': u'cingulate cortex',
#   u'co-occ_count': 1354,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383aea6387de73a8afb0'),
#   u'bregion': u'anterior cingulate cortex',
#   u'co-occ_count': 1334,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383bea6387de73a8cef6'),
#   u'bregion': u'cingulate cortex',
#   u'co-occ_count': 1306,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('55683839ea6387de73a8a4de'),
#   u'bregion': u'anterior cingulate cortex',
#   u'co-occ_count': 1295,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383bea6387de73a8c828'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 1289,
#   u'scale': u'sib'},
#  {u'_id': ObjectId('5568383aea6387de73a8c3e9'),
#   u'bregion': u'posterior cingulate',
#   u'co-occ_count': 1281,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8b0d9'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 1274,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383bea6387de73a8ca45'),
#   u'bregion': u'parietal cortex',
#   u'co-occ_count': 1269,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('55683839ea6387de73a8aeb3'),
#   u'bregion': u'basal ganglia',
#   u'co-occ_count': 1262,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383cea6387de73a8db10'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 1260,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383bea6387de73a8cad1'),
#   u'bregion': u'frontal lobe',
#   u'co-occ_count': 1257,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383bea6387de73a8d85e'),
#   u'bregion': u'motor cortex',
#   u'co-occ_count': 1255,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383bea6387de73a8c5b9'),
#   u'bregion': u'motor area',
#   u'co-occ_count': 1241,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383bea6387de73a8cde7'),
#   u'bregion': u'temporal gyrus',
#   u'co-occ_count': 1234,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8c338'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 1227,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('5568383aea6387de73a8b153'),
#   u'bregion': u'cuneus',
#   u'co-occ_count': 1223,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8b8e2'),
#   u'bregion': u'inferior frontal gyrus',
#   u'co-occ_count': 1213,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383bea6387de73a8d442'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 1210,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383bea6387de73a8c9bb'),
#   u'bregion': u'basal ganglia',
#   u'co-occ_count': 1180,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383bea6387de73a8cb0a'),
#   u'bregion': u'parietal cortex',
#   u'co-occ_count': 1176,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383bea6387de73a8d43c'),
#   u'bregion': u'motor cortex',
#   u'co-occ_count': 1167,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383bea6387de73a8cc0d'),
#   u'bregion': u'motor cortex',
#   u'co-occ_count': 1146,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383aea6387de73a8b84a'),
#   u'bregion': u'anterior cingulate cortex',
#   u'co-occ_count': 1140,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('55683839ea6387de73a8a966'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 1129,
#   u'scale': u'pic'},
#  {u'_id': ObjectId('55683839ea6387de73a8ab2b'),
#   u'bregion': u'motor cortex',
#   u'co-occ_count': 1121,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('55683839ea6387de73a8a9a1'),
#   u'bregion': u'frontal lobe',
#   u'co-occ_count': 1120,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('55683839ea6387de73a8ae33'),
#   u'bregion': u'visual cortex',
#   u'co-occ_count': 1110,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('55683839ea6387de73a8a44d'),
#   u'bregion': u'orbitofrontal cortex',
#   u'co-occ_count': 1100,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383bea6387de73a8cda5'),
#   u'bregion': u'temporal lobe',
#   u'co-occ_count': 1098,
#   u'scale': u'pal'},
#  {u'_id': ObjectId('5568383aea6387de73a8c00e'),
#   u'bregion': u'parietal cortex',
#   u'co-occ_count': 1088,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('55683839ea6387de73a8aeec'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 1076,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('5568383aea6387de73a8b9ba'),
#   u'bregion': u'precuneus',
#   u'co-occ_count': 1073,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8b90e'),
#   u'bregion': u'frontal lobe',
#   u'co-occ_count': 1043,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383bea6387de73a8d373'),
#   u'bregion': u'temporal cortex',
#   u'co-occ_count': 1042,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383cea6387de73a8dad5'),
#   u'bregion': u'parietal cortex',
#   u'co-occ_count': 1038,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b80d'),
#   u'bregion': u'frontal lobe',
#   u'co-occ_count': 1024,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383bea6387de73a8d9cb'),
#   u'bregion': u'parietal cortex',
#   u'co-occ_count': 1022,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383bea6387de73a8cada'),
#   u'bregion': u'anterior cingulate cortex',
#   u'co-occ_count': 1000,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('55683839ea6387de73a8a262'),
#   u'bregion': u'basal ganglia',
#   u'co-occ_count': 988,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383bea6387de73a8da3e'),
#   u'bregion': u'basal ganglia',
#   u'co-occ_count': 988,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383bea6387de73a8d5a8'),
#   u'bregion': u'anterior cingulate cortex',
#   u'co-occ_count': 972,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383aea6387de73a8c490'),
#   u'bregion': u'corpus callosum',
#   u'co-occ_count': 967,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383bea6387de73a8c664'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 966,
#   u'scale': u'sib'},
#  {u'_id': ObjectId('55683839ea6387de73a8aa01'),
#   u'bregion': u'parietal region',
#   u'co-occ_count': 964,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383bea6387de73a8d311'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 958,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('5568383cea6387de73a8dbf3'),
#   u'bregion': u'motor cortex',
#   u'co-occ_count': 950,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383aea6387de73a8bd8b'),
#   u'bregion': u'frontal lobe',
#   u'co-occ_count': 940,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383bea6387de73a8d6cd'),
#   u'bregion': u'basal ganglia',
#   u'co-occ_count': 938,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('55683839ea6387de73a8a415'),
#   u'bregion': u'parietal cortex',
#   u'co-occ_count': 922,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383cea6387de73a8dbfc'),
#   u'bregion': u'temporal lobe',
#   u'co-occ_count': 916,
#   u'scale': u'cri'},
#  {u'_id': ObjectId('5568383aea6387de73a8b247'),
#   u'bregion': u'anterior cingulate cortex',
#   u'co-occ_count': 914,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383aea6387de73a8b5de'),
#   u'bregion': u'anterior cingulate cortex',
#   u'co-occ_count': 909,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383bea6387de73a8d364'),
#   u'bregion': u'temporal gyrus',
#   u'co-occ_count': 905,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383cea6387de73a8de26'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 905,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('55683839ea6387de73a8a412'),
#   u'bregion': u'posterior cingulate',
#   u'co-occ_count': 901,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b68c'),
#   u'bregion': u'parietal lobe',
#   u'co-occ_count': 900,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383cea6387de73a8db13'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 896,
#   u'scale': u'sib'},
#  {u'_id': ObjectId('5568383bea6387de73a8ca19'),
#   u'bregion': u'basal ganglia',
#   u'co-occ_count': 886,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383aea6387de73a8b89b'),
#   u'bregion': u'motor cortex',
#   u'co-occ_count': 879,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383aea6387de73a8b4ad'),
#   u'bregion': u'posterior cingulate',
#   u'co-occ_count': 875,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383aea6387de73a8b8b7'),
#   u'bregion': u'motor cortex',
#   u'co-occ_count': 871,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383aea6387de73a8b013'),
#   u'bregion': u'putamen',
#   u'co-occ_count': 864,
#   u'scale': u'amen'},
#  {u'_id': ObjectId('55683839ea6387de73a8a428'),
#   u'bregion': u'temporal lobe',
#   u'co-occ_count': 857,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('5568383bea6387de73a8d484'),
#   u'bregion': u'parietal cortex',
#   u'co-occ_count': 857,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383aea6387de73a8beff'),
#   u'bregion': u'posterior cingulate',
#   u'co-occ_count': 854,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383cea6387de73a8dd55'),
#   u'bregion': u'cuneus',
#   u'co-occ_count': 854,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383aea6387de73a8ba70'),
#   u'bregion': u'inferior frontal gyrus',
#   u'co-occ_count': 852,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383bea6387de73a8d4c2'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 847,
#   u'scale': u'pal'},
#  {u'_id': ObjectId('55683839ea6387de73a8a5eb'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 845,
#   u'scale': u'pic'},
#  {u'_id': ObjectId('5568383aea6387de73a8b24b'),
#   u'bregion': u'putamen',
#   u'co-occ_count': 840,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('55683839ea6387de73a8aef0'),
#   u'bregion': u'motor area',
#   u'co-occ_count': 837,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383aea6387de73a8c3e0'),
#   u'bregion': u'orbitofrontal cortex',
#   u'co-occ_count': 832,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383aea6387de73a8b4fd'),
#   u'bregion': u'temporal region',
#   u'co-occ_count': 830,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('55683839ea6387de73a8a352'),
#   u'bregion': u'temporal gyrus',
#   u'co-occ_count': 825,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383aea6387de73a8b7b7'),
#   u'bregion': u'hypothalamus',
#   u'co-occ_count': 818,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('55683839ea6387de73a8af1f'),
#   u'bregion': u'cingulate cortex',
#   u'co-occ_count': 811,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('5568383bea6387de73a8cd41'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 810,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('5568383aea6387de73a8bb65'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 809,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('5568383bea6387de73a8d936'),
#   u'bregion': u'frontal lobe',
#   u'co-occ_count': 808,
#   u'scale': u'pai'},
#  {u'_id': ObjectId('5568383aea6387de73a8b693'),
#   u'bregion': u'cuneus',
#   u'co-occ_count': 804,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383bea6387de73a8d5ef'),
#   u'bregion': u'temporal gyrus',
#   u'co-occ_count': 800,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('55683839ea6387de73a8a6d3'),
#   u'bregion': u'cuneus',
#   u'co-occ_count': 799,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383aea6387de73a8bd4f'),
#   u'bregion': u'visual cortex',
#   u'co-occ_count': 799,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383bea6387de73a8ceeb'),
#   u'bregion': u'parietal regions',
#   u'co-occ_count': 798,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8b7e3'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 797,
#   u'scale': u'cri'},
#  {u'_id': ObjectId('5568383aea6387de73a8ba0c'),
#   u'bregion': u'visual cortex',
#   u'co-occ_count': 788,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383aea6387de73a8afd7'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 786,
#   u'scale': u'pai'},
#  {u'_id': ObjectId('55683839ea6387de73a8a35d'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 786,
#   u'scale': u'pai'},
#  {u'_id': ObjectId('5568383aea6387de73a8be05'),
#   u'bregion': u'temporal cortex',
#   u'co-occ_count': 784,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383aea6387de73a8b904'),
#   u'bregion': u'parietal lobule',
#   u'co-occ_count': 783,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8af52'),
#   u'bregion': u'orbitofrontal cortex',
#   u'co-occ_count': 777,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383aea6387de73a8bec8'),
#   u'bregion': u'inferior frontal gyrus',
#   u'co-occ_count': 776,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383aea6387de73a8be15'),
#   u'bregion': u'temporal lobe',
#   u'co-occ_count': 770,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('55683839ea6387de73a8af2b'),
#   u'bregion': u'posterior cingulate',
#   u'co-occ_count': 758,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383aea6387de73a8bbcf'),
#   u'bregion': u'precuneus',
#   u'co-occ_count': 753,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383aea6387de73a8c32a'),
#   u'bregion': u'visual cortex',
#   u'co-occ_count': 735,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b8d4'),
#   u'bregion': u'motor area',
#   u'co-occ_count': 733,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383aea6387de73a8bf63'),
#   u'bregion': u'motor area',
#   u'co-occ_count': 733,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383cea6387de73a8df13'),
#   u'bregion': u'corpus callosum',
#   u'co-occ_count': 729,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('55683839ea6387de73a8ad33'),
#   u'bregion': u'cuneus',
#   u'co-occ_count': 719,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('55683839ea6387de73a8aab5'),
#   u'bregion': u'posterior cingulate',
#   u'co-occ_count': 718,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('55683839ea6387de73a8a6c7'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 715,
#   u'scale': u'cri'},
#  {u'_id': ObjectId('55683839ea6387de73a8aa1f'),
#   u'bregion': u'visual cortex',
#   u'co-occ_count': 713,
#   u'scale': u'da'},
#  {u'_id': ObjectId('55683839ea6387de73a8a5ca'),
#   u'bregion': u'temporal cortex',
#   u'co-occ_count': 709,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b84d'),
#   u'bregion': u'temporal gyrus',
#   u'co-occ_count': 708,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383cea6387de73a8ddb4'),
#   u'bregion': u'inferior frontal gyrus',
#   u'co-occ_count': 707,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383aea6387de73a8bfb5'),
#   u'bregion': u'visual cortex',
#   u'co-occ_count': 704,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('55683839ea6387de73a8a40b'),
#   u'bregion': u'precuneus',
#   u'co-occ_count': 703,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383bea6387de73a8d1e2'),
#   u'bregion': u'orbitofrontal cortex',
#   u'co-occ_count': 703,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b96f'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 701,
#   u'scale': u'pai'},
#  {u'_id': ObjectId('5568383bea6387de73a8d1ff'),
#   u'bregion': u'putamen',
#   u'co-occ_count': 701,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383aea6387de73a8c469'),
#   u'bregion': u'precuneus',
#   u'co-occ_count': 697,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383aea6387de73a8b41b'),
#   u'bregion': u'temporal cortex',
#   u'co-occ_count': 694,
#   u'scale': u'da'},
#  {u'_id': ObjectId('55683839ea6387de73a8aaee'),
#   u'bregion': u'corpus callosum',
#   u'co-occ_count': 693,
#   u'scale': u'da'},
#  {u'_id': ObjectId('55683839ea6387de73a8a89b'),
#   u'bregion': u'cingulate cortex',
#   u'co-occ_count': 690,
#   u'scale': u'pai'},
#  {u'_id': ObjectId('5568383aea6387de73a8b2fb'),
#   u'bregion': u'parietal lobe',
#   u'co-occ_count': 689,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b01c'),
#   u'bregion': u'temporal gyrus',
#   u'co-occ_count': 689,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383cea6387de73a8dedc'),
#   u'bregion': u'temporal gyrus',
#   u'co-occ_count': 688,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b141'),
#   u'bregion': u'superior temporal gyrus',
#   u'co-occ_count': 687,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('55683839ea6387de73a8a5d3'),
#   u'bregion': u'posterior cingulate',
#   u'co-occ_count': 685,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383bea6387de73a8c571'),
#   u'bregion': u'cuneus',
#   u'co-occ_count': 683,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('55683839ea6387de73a8a948'),
#   u'bregion': u'temporal lobes',
#   u'co-occ_count': 680,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('55683839ea6387de73a8a24e'),
#   u'bregion': u'motor area',
#   u'co-occ_count': 679,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383aea6387de73a8c1aa'),
#   u'bregion': u'cingulate cortex',
#   u'co-occ_count': 672,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('5568383bea6387de73a8ccd9'),
#   u'bregion': u'parietal region',
#   u'co-occ_count': 672,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383bea6387de73a8c8fb'),
#   u'bregion': u'visual cortex',
#   u'co-occ_count': 668,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383bea6387de73a8d49d'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 660,
#   u'scale': u'abs'},
#  {u'_id': ObjectId('5568383aea6387de73a8baca'),
#   u'bregion': u'motor area',
#   u'co-occ_count': 655,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383bea6387de73a8cc65'),
#   u'bregion': u'cuneus',
#   u'co-occ_count': 655,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383bea6387de73a8d8c7'),
#   u'bregion': u'supplementary motor area',
#   u'co-occ_count': 655,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8b003'),
#   u'bregion': u'hypothalamus',
#   u'co-occ_count': 654,
#   u'scale': u'da'},
#  {u'_id': ObjectId('55683839ea6387de73a8a676'),
#   u'bregion': u'temporal lobe',
#   u'co-occ_count': 654,
#   u'scale': u'cas'},
#  {u'_id': ObjectId('5568383cea6387de73a8e060'),
#   u'bregion': u'cingulate gyrus',
#   u'co-occ_count': 653,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8b62f'),
#   u'bregion': u'inferior frontal gyrus',
#   u'co-occ_count': 649,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383aea6387de73a8bf95'),
#   u'bregion': u'cuneus',
#   u'co-occ_count': 647,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383bea6387de73a8c5d5'),
#   u'bregion': u'inferior frontal gyrus',
#   u'co-occ_count': 645,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('55683839ea6387de73a8a43c'),
#   u'bregion': u'hypothalamus',
#   u'co-occ_count': 641,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383aea6387de73a8bc51'),
#   u'bregion': u'motor area',
#   u'co-occ_count': 640,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('55683839ea6387de73a8a301'),
#   u'bregion': u'posterior cingulate',
#   u'co-occ_count': 639,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('55683839ea6387de73a8a257'),
#   u'bregion': u'precuneus',
#   u'co-occ_count': 637,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('55683839ea6387de73a8a70d'),
#   u'bregion': u'temporal regions',
#   u'co-occ_count': 633,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383bea6387de73a8d916'),
#   u'bregion': u'motor area',
#   u'co-occ_count': 632,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383cea6387de73a8e08e'),
#   u'bregion': u'inferior frontal gyrus',
#   u'co-occ_count': 629,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b852'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 628,
#   u'scale': u'pal'},
#  {u'_id': ObjectId('5568383aea6387de73a8bc61'),
#   u'bregion': u'basal ganglia',
#   u'co-occ_count': 626,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('5568383bea6387de73a8c9cf'),
#   u'bregion': u'corpus callosum',
#   u'co-occ_count': 626,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383aea6387de73a8bde6'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 620,
#   u'scale': u'pal'},
#  {u'_id': ObjectId('5568383bea6387de73a8cfd9'),
#   u'bregion': u'parietal lobe',
#   u'co-occ_count': 617,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383aea6387de73a8b8da'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 615,
#   u'scale': u'cas'},
#  {u'_id': ObjectId('5568383aea6387de73a8bcef'),
#   u'bregion': u'parietal region',
#   u'co-occ_count': 615,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383bea6387de73a8cca8'),
#   u'bregion': u'premotor cortex',
#   u'co-occ_count': 615,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('55683839ea6387de73a8a688'),
#   u'bregion': u'putamen',
#   u'co-occ_count': 612,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383cea6387de73a8deea'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 612,
#   u'scale': u'pic'},
#  {u'_id': ObjectId('55683839ea6387de73a8aacd'),
#   u'bregion': u'parietal region',
#   u'co-occ_count': 608,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383aea6387de73a8bbb3'),
#   u'bregion': u'cerebral cortex',
#   u'co-occ_count': 608,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8b632'),
#   u'bregion': u'temporal region',
#   u'co-occ_count': 605,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383aea6387de73a8bed6'),
#   u'bregion': u'temporal gyrus',
#   u'co-occ_count': 605,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383aea6387de73a8b894'),
#   u'bregion': u'precuneus',
#   u'co-occ_count': 602,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383bea6387de73a8cbdb'),
#   u'bregion': u'temporal region',
#   u'co-occ_count': 600,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383aea6387de73a8babc'),
#   u'bregion': u'temporal cortex',
#   u'co-occ_count': 594,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383bea6387de73a8caa6'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 594,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('5568383aea6387de73a8c169'),
#   u'bregion': u'temporal cortex',
#   u'co-occ_count': 593,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383aea6387de73a8c119'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 592,
#   u'scale': u'rist'},
#  {u'_id': ObjectId('5568383aea6387de73a8b04d'),
#   u'bregion': u'orbitofrontal cortex',
#   u'co-occ_count': 589,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('55683839ea6387de73a8a7f7'),
#   u'bregion': u'temporal lobe',
#   u'co-occ_count': 589,
#   u'scale': u'sib'},
#  {u'_id': ObjectId('5568383bea6387de73a8cf86'),
#   u'bregion': u'basal ganglia',
#   u'co-occ_count': 586,
#   u'scale': u'pai'},
#  {u'_id': ObjectId('5568383aea6387de73a8b1ed'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 585,
#   u'scale': u'dar'},
#  {u'_id': ObjectId('5568383aea6387de73a8b1bc'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 583,
#   u'scale': u'cas'},
#  {u'_id': ObjectId('55683839ea6387de73a8ad60'),
#   u'bregion': u'frontal lobe',
#   u'co-occ_count': 582,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('5568383aea6387de73a8c499'),
#   u'bregion': u'corpus callosum',
#   u'co-occ_count': 582,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383aea6387de73a8b52e'),
#   u'bregion': u'fusiform gyrus',
#   u'co-occ_count': 581,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8b12c'),
#   u'bregion': u'anterior cingulate cortex',
#   u'co-occ_count': 581,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('55683839ea6387de73a8a479'),
#   u'bregion': u'precuneus',
#   u'co-occ_count': 580,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383bea6387de73a8d7dc'),
#   u'bregion': u'inferior frontal gyrus',
#   u'co-occ_count': 578,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383aea6387de73a8bbbc'),
#   u'bregion': u'hypothalamus',
#   u'co-occ_count': 576,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383cea6387de73a8dd84'),
#   u'bregion': u'occipital cortex',
#   u'co-occ_count': 575,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('55683839ea6387de73a8a9aa'),
#   u'bregion': u'temporal lobes',
#   u'co-occ_count': 570,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('55683839ea6387de73a8a2ec'),
#   u'bregion': u'temporal cortex',
#   u'co-occ_count': 570,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383bea6387de73a8d9ff'),
#   u'bregion': u'posterior parietal cortex',
#   u'co-occ_count': 565,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383bea6387de73a8c509'),
#   u'bregion': u'parietal lobe',
#   u'co-occ_count': 564,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383aea6387de73a8b1d5'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 563,
#   u'scale': u'cri'},
#  {u'_id': ObjectId('5568383aea6387de73a8bf8b'),
#   u'bregion': u'posterior cingulate cortex',
#   u'co-occ_count': 563,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8c21e'),
#   u'bregion': u'temporal lobe',
#   u'co-occ_count': 562,
#   u'scale': u'pic'},
#  {u'_id': ObjectId('5568383aea6387de73a8b3a4'),
#   u'bregion': u'orbitofrontal cortex',
#   u'co-occ_count': 561,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('55683839ea6387de73a8aab2'),
#   u'bregion': u'putamen',
#   u'co-occ_count': 561,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383bea6387de73a8d2f5'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 561,
#   u'scale': u'amen'},
#  {u'_id': ObjectId('55683839ea6387de73a8aa08'),
#   u'bregion': u'precuneus',
#   u'co-occ_count': 560,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b31c'),
#   u'bregion': u'orbitofrontal cortex',
#   u'co-occ_count': 559,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('55683839ea6387de73a8a27d'),
#   u'bregion': u'temporal cortex',
#   u'co-occ_count': 557,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('55683839ea6387de73a8a9a3'),
#   u'bregion': u'ventral striatum',
#   u'co-occ_count': 555,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8b53f'),
#   u'bregion': u'primary motor cortex',
#   u'co-occ_count': 553,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8b608'),
#   u'bregion': u'motor cortex',
#   u'co-occ_count': 551,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('5568383aea6387de73a8c2d8'),
#   u'bregion': u'parietal regions',
#   u'co-occ_count': 550,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383bea6387de73a8d042'),
#   u'bregion': u'parietal cortex',
#   u'co-occ_count': 550,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('55683839ea6387de73a8a754'),
#   u'bregion': u'temporal region',
#   u'co-occ_count': 547,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383aea6387de73a8bbe1'),
#   u'bregion': u'corpus callosum',
#   u'co-occ_count': 538,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('55683839ea6387de73a8acba'),
#   u'bregion': u'intraparietal sulcus',
#   u'co-occ_count': 536,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('55683839ea6387de73a8a599'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 536,
#   u'scale': u'pic'},
#  {u'_id': ObjectId('5568383bea6387de73a8c944'),
#   u'bregion': u'frontal cortices',
#   u'co-occ_count': 535,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('55683839ea6387de73a8a956'),
#   u'bregion': u'motor areas',
#   u'co-occ_count': 533,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('55683839ea6387de73a8ad75'),
#   u'bregion': u'midbrain',
#   u'co-occ_count': 532,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8bacc'),
#   u'bregion': u'visual cortex',
#   u'co-occ_count': 523,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383aea6387de73a8c333'),
#   u'bregion': u'parietal region',
#   u'co-occ_count': 519,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('55683839ea6387de73a8ae21'),
#   u'bregion': u'orbitofrontal cortex',
#   u'co-occ_count': 518,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383aea6387de73a8b56a'),
#   u'bregion': u'hippocampal gyrus',
#   u'co-occ_count': 517,
#   u'scale': u'pal'},
#  {u'_id': ObjectId('5568383aea6387de73a8bd04'),
#   u'bregion': u'parietal lobule',
#   u'co-occ_count': 514,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383bea6387de73a8cf8b'),
#   u'bregion': u'parietal lobule',
#   u'co-occ_count': 512,
#   u'scale': u'da'},
#  {u'_id': ObjectId('55683839ea6387de73a8a514'),
#   u'bregion': u'parietal cortex',
#   u'co-occ_count': 509,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('5568383aea6387de73a8bda3'),
#   u'bregion': u'frontal lobes',
#   u'co-occ_count': 508,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('55683839ea6387de73a8a4ad'),
#   u'bregion': u'superior temporal gyrus',
#   u'co-occ_count': 506,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('55683839ea6387de73a8ae6a'),
#   u'bregion': u'parahippocampal gyrus',
#   u'co-occ_count': 505,
#   u'scale': u'pal'},
#  {u'_id': ObjectId('5568383aea6387de73a8bc63'),
#   u'bregion': u'parietal lobe',
#   u'co-occ_count': 505,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383aea6387de73a8bdda'),
#   u'bregion': u'caudate nucleus',
#   u'co-occ_count': 505,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383bea6387de73a8d2b8'),
#   u'bregion': u'hippocampal gyrus',
#   u'co-occ_count': 504,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383bea6387de73a8c59f'),
#   u'bregion': u'parietal region',
#   u'co-occ_count': 503,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383aea6387de73a8b36d'),
#   u'bregion': u'parietal region',
#   u'co-occ_count': 499,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('55683839ea6387de73a8ac1e'),
#   u'bregion': u'temporal lobes',
#   u'co-occ_count': 499,
#   u'scale': u'da'},
#  {u'_id': ObjectId('55683839ea6387de73a8aa0b'),
#   u'bregion': u'parietal regions',
#   u'co-occ_count': 499,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383aea6387de73a8c4a0'),
#   u'bregion': u'motor cortex',
#   u'co-occ_count': 499,
#   u'scale': u'pai'},
#  {u'_id': ObjectId('5568383cea6387de73a8dca9'),
#   u'bregion': u'parietal regions',
#   u'co-occ_count': 499,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383bea6387de73a8ca97'),
#   u'bregion': u'caudate nucleus',
#   u'co-occ_count': 495,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383bea6387de73a8d48a'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 495,
#   u'scale': u'abs'},
#  {u'_id': ObjectId('55683839ea6387de73a8a4e5'),
#   u'bregion': u'parahippocampal gyrus',
#   u'co-occ_count': 492,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('55683839ea6387de73a8a3ac'),
#   u'bregion': u'temporal region',
#   u'co-occ_count': 492,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383aea6387de73a8b1d4'),
#   u'bregion': u'corpus callosum',
#   u'co-occ_count': 489,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383bea6387de73a8cac3'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 488,
#   u'scale': u'dap'},
#  {u'_id': ObjectId('5568383bea6387de73a8d4e3'),
#   u'bregion': u'parietal region',
#   u'co-occ_count': 487,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383aea6387de73a8c37b'),
#   u'bregion': u'nucleus accumbens',
#   u'co-occ_count': 485,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8b90c'),
#   u'bregion': u'corpus callosum',
#   u'co-occ_count': 483,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('55683839ea6387de73a8a638'),
#   u'bregion': u'parietal lobe',
#   u'co-occ_count': 483,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383bea6387de73a8c674'),
#   u'bregion': u'cingulate cortex',
#   u'co-occ_count': 482,
#   u'scale': u'cri'},
#  {u'_id': ObjectId('5568383bea6387de73a8cb4b'),
#   u'bregion': u'cingulate gyrus',
#   u'co-occ_count': 480,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383bea6387de73a8d6ba'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 480,
#   u'scale': u'aps'},
#  {u'_id': ObjectId('5568383bea6387de73a8cc5a'),
#   u'bregion': u'parietal lobe',
#   u'co-occ_count': 477,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383aea6387de73a8bb00'),
#   u'bregion': u'auditory cortex',
#   u'co-occ_count': 475,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8bcb8'),
#   u'bregion': u'putamen',
#   u'co-occ_count': 473,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('55683839ea6387de73a8a3fc'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 470,
#   u'scale': u'toni'},
#  {u'_id': ObjectId('55683839ea6387de73a8aadd'),
#   u'bregion': u'basal ganglia',
#   u'co-occ_count': 469,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('55683839ea6387de73a8a327'),
#   u'bregion': u'superior temporal gyrus',
#   u'co-occ_count': 469,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b273'),
#   u'bregion': u'anterior cingulate cortex',
#   u'co-occ_count': 468,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('5568383aea6387de73a8b3c1'),
#   u'bregion': u'ventromedial prefrontal cortex',
#   u'co-occ_count': 467,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8bc6e'),
#   u'bregion': u'parietal lobule',
#   u'co-occ_count': 466,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383aea6387de73a8b980'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 465,
#   u'scale': u'nab'},
#  {u'_id': ObjectId('5568383aea6387de73a8b128'),
#   u'bregion': u'cingulate gyrus',
#   u'co-occ_count': 465,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('55683839ea6387de73a8af15'),
#   u'bregion': u'temporal lobes',
#   u'co-occ_count': 464,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383cea6387de73a8de23'),
#   u'bregion': u'temporal regions',
#   u'co-occ_count': 463,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383aea6387de73a8b43a'),
#   u'bregion': u'hypothalamus',
#   u'co-occ_count': 462,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383aea6387de73a8c22a'),
#   u'bregion': u'corpus callosum',
#   u'co-occ_count': 462,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('5568383aea6387de73a8c39f'),
#   u'bregion': u'superior temporal gyrus',
#   u'co-occ_count': 461,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383bea6387de73a8d893'),
#   u'bregion': u'cerebral cortex',
#   u'co-occ_count': 461,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383cea6387de73a8dd59'),
#   u'bregion': u'frontal lobe',
#   u'co-occ_count': 459,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('5568383bea6387de73a8cd1b'),
#   u'bregion': u'supplementary motor area',
#   u'co-occ_count': 458,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383bea6387de73a8d391'),
#   u'bregion': u'frontal lobe',
#   u'co-occ_count': 458,
#   u'scale': u'cri'},
#  {u'_id': ObjectId('5568383cea6387de73a8df91'),
#   u'bregion': u'cerebral cortex',
#   u'co-occ_count': 458,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383aea6387de73a8b794'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 456,
#   u'scale': u'sib'},
#  {u'_id': ObjectId('5568383cea6387de73a8dd95'),
#   u'bregion': u'hypothalamus',
#   u'co-occ_count': 453,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b1f2'),
#   u'bregion': u'temporal regions',
#   u'co-occ_count': 452,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('55683839ea6387de73a8ab6e'),
#   u'bregion': u'temporal region',
#   u'co-occ_count': 449,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('55683839ea6387de73a8a790'),
#   u'bregion': u'anterior cingulate cortex',
#   u'co-occ_count': 449,
#   u'scale': u'pai'},
#  {u'_id': ObjectId('5568383aea6387de73a8b152'),
#   u'bregion': u'cingulate gyrus',
#   u'co-occ_count': 448,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383bea6387de73a8d8ed'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 447,
#   u'scale': u'dar'},
#  {u'_id': ObjectId('5568383aea6387de73a8c0f7'),
#   u'bregion': u'fusiform gyrus',
#   u'co-occ_count': 446,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('55683839ea6387de73a8aac5'),
#   u'bregion': u'cerebral cortex',
#   u'co-occ_count': 445,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383aea6387de73a8befb'),
#   u'bregion': u'parietal lobule',
#   u'co-occ_count': 443,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383bea6387de73a8d76d'),
#   u'bregion': u'posterior cingulate',
#   u'co-occ_count': 440,
#   u'scale': u'pai'},
#  {u'_id': ObjectId('5568383bea6387de73a8cd07'),
#   u'bregion': u'basal ganglia',
#   u'co-occ_count': 439,
#   u'scale': u'cri'},
#  {u'_id': ObjectId('5568383bea6387de73a8d3d0'),
#   u'bregion': u'parietal cortex',
#   u'co-occ_count': 439,
#   u'scale': u'pai'},
#  {u'_id': ObjectId('5568383bea6387de73a8c967'),
#   u'bregion': u'parietal regions',
#   u'co-occ_count': 435,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383cea6387de73a8de8b'),
#   u'bregion': u'parietal lobule',
#   u'co-occ_count': 435,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383aea6387de73a8bba9'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 433,
#   u'scale': u'rist'},
#  {u'_id': ObjectId('55683839ea6387de73a8ac3b'),
#   u'bregion': u'parietal lobe',
#   u'co-occ_count': 431,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383aea6387de73a8bb6f'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 431,
#   u'scale': u'bta'},
#  {u'_id': ObjectId('5568383aea6387de73a8b230'),
#   u'bregion': u'parietal lobule',
#   u'co-occ_count': 429,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b18c'),
#   u'bregion': u'putamen',
#   u'co-occ_count': 428,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383cea6387de73a8ded3'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 426,
#   u'scale': u'cas'},
#  {u'_id': ObjectId('55683839ea6387de73a8a957'),
#   u'bregion': u'occipital cortex',
#   u'co-occ_count': 424,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383bea6387de73a8d5d7'),
#   u'bregion': u'motor cortex',
#   u'co-occ_count': 424,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('5568383bea6387de73a8d16f'),
#   u'bregion': u'parietal regions',
#   u'co-occ_count': 423,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383aea6387de73a8bc08'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 420,
#   u'scale': u'aps'},
#  {u'_id': ObjectId('5568383bea6387de73a8c7dc'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 419,
#   u'scale': u'amen'},
#  {u'_id': ObjectId('5568383aea6387de73a8bc09'),
#   u'bregion': u'temporal sulcus',
#   u'co-occ_count': 416,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383bea6387de73a8d02a'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 416,
#   u'scale': u'sib'},
#  {u'_id': ObjectId('5568383aea6387de73a8b3dd'),
#   u'bregion': u'hypothalamus',
#   u'co-occ_count': 415,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383cea6387de73a8db4b'),
#   u'bregion': u'temporal region',
#   u'co-occ_count': 414,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('55683839ea6387de73a8a5bf'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 413,
#   u'scale': u'sib'},
#  {u'_id': ObjectId('5568383bea6387de73a8caf1'),
#   u'bregion': u'putamen',
#   u'co-occ_count': 412,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383bea6387de73a8da9b'),
#   u'bregion': u'ventral striatum',
#   u'co-occ_count': 412,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383aea6387de73a8b1cf'),
#   u'bregion': u'temporal region',
#   u'co-occ_count': 411,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383aea6387de73a8b38a'),
#   u'bregion': u'hypothalamus',
#   u'co-occ_count': 409,
#   u'scale': u'cri'},
#  {u'_id': ObjectId('5568383aea6387de73a8afbd'),
#   u'bregion': u'dentate gyrus',
#   u'co-occ_count': 409,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('55683839ea6387de73a8a3e0'),
#   u'bregion': u'parietal regions',
#   u'co-occ_count': 409,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383cea6387de73a8e04d'),
#   u'bregion': u'temporal regions',
#   u'co-occ_count': 405,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383cea6387de73a8dd2d'),
#   u'bregion': u'fusiform gyrus',
#   u'co-occ_count': 404,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383bea6387de73a8d415'),
#   u'bregion': u'putamen',
#   u'co-occ_count': 403,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b702'),
#   u'bregion': u'temporal lobes',
#   u'co-occ_count': 402,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383aea6387de73a8b059'),
#   u'bregion': u'midbrain',
#   u'co-occ_count': 402,
#   u'scale': u'da'},
#  {u'_id': ObjectId('55683839ea6387de73a8a9b9'),
#   u'bregion': u'ventral striatum',
#   u'co-occ_count': 402,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('55683839ea6387de73a8a68f'),
#   u'bregion': u'forebrain',
#   u'co-occ_count': 402,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8afb5'),
#   u'bregion': u'subthalamic nucleus',
#   u'co-occ_count': 401,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('55683839ea6387de73a8ae07'),
#   u'bregion': u'cuneus',
#   u'co-occ_count': 401,
# ...
#  {u'_id': ObjectId('5568383bea6387de73a8cbb1'),
#   u'bregion': u'motor cortex',
#   u'co-occ_count': 168,
#   u'scale': u'rist'},
#  {u'_id': ObjectId('5568383aea6387de73a8ba9e'),
#   u'bregion': u'entorhinal cortex',
#   u'co-occ_count': 167,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b25b'),
#   u'bregion': u'temporal cortices',
#   u'co-occ_count': 167,
#   u'scale': u'da'},
#  {u'_id': ObjectId('55683839ea6387de73a8ab46'),
#   u'bregion': u'fusiform gyrus',
#   u'co-occ_count': 167,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('55683839ea6387de73a8a87e'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 167,
#   u'scale': u'ils'},
#  {u'_id': ObjectId('55683839ea6387de73a8a28c'),
#   u'bregion': u'marginal gyrus',
#   u'co-occ_count': 167,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383aea6387de73a8c0b0'),
#   u'bregion': u'fusiform gyrus',
#   u'co-occ_count': 167,
#   u'scale': u'pai'},
#  {u'_id': ObjectId('5568383aea6387de73a8b469'),
#   u'bregion': u'basal ganglia',
#   u'co-occ_count': 166,
#   u'scale': u'dar'},
#  {u'_id': ObjectId('55683839ea6387de73a8ab7c'),
#   u'bregion': u'posterior cingulate',
#   u'co-occ_count': 166,
#   u'scale': u'pic'},
#  {u'_id': ObjectId('55683839ea6387de73a8aac7'),
#   u'bregion': u'anterior cingulate gyrus',
#   u'co-occ_count': 166,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383bea6387de73a8d58d'),
#   u'bregion': u'frontal cortex',
#   u'co-occ_count': 166,
#   u'scale': u'psi'},
#  {u'_id': ObjectId('5568383aea6387de73a8baa5'),
#   u'bregion': u'supplementary motor area',
#   u'co-occ_count': 165,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('5568383aea6387de73a8b251'),
#   u'bregion': u'somatosensory cortex',
#   u'co-occ_count': 165,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383aea6387de73a8beb0'),
#   u'bregion': u'angular gyrus',
#   u'co-occ_count': 165,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b4fc'),
#   u'bregion': u'hypothalamus',
#   u'co-occ_count': 164,
#   u'scale': u'sib'},
#  {u'_id': ObjectId('5568383aea6387de73a8b100'),
#   u'bregion': u'posterior parietal cortex',
#   u'co-occ_count': 164,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('5568383aea6387de73a8c4aa'),
#   u'bregion': u'cingulate cortex',
#   u'co-occ_count': 164,
#   u'scale': u'dap'},
#  {u'_id': ObjectId('5568383bea6387de73a8d4b8'),
#   u'bregion': u'parahippocampal gyrus',
#   u'co-occ_count': 164,
#   u'scale': u'pai'},
#  {u'_id': ObjectId('5568383bea6387de73a8d937'),
#   u'bregion': u'occipital region',
#   u'co-occ_count': 164,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b453'),
#   u'bregion': u'parietal lobes',
#   u'co-occ_count': 163,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383aea6387de73a8bfdf'),
#   u'bregion': u'hippocampal formation',
#   u'co-occ_count': 163,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383bea6387de73a8c99f'),
#   u'bregion': u'superior frontal gyrus',
#   u'co-occ_count': 163,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383bea6387de73a8d048'),
#   u'bregion': u'globus pallidus',
#   u'co-occ_count': 163,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('55683839ea6387de73a8adbb'),
#   u'bregion': u'midbrain',
#   u'co-occ_count': 162,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('5568383aea6387de73a8bd30'),
#   u'bregion': u'hippocampal formation',
#   u'co-occ_count': 162,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383aea6387de73a8bda8'),
#   u'bregion': u'marginal gyrus',
#   u'co-occ_count': 162,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b17e'),
#   u'bregion': u'cerebral cortex',
#   u'co-occ_count': 161,
#   u'scale': u'cri'},
#  {u'_id': ObjectId('5568383aea6387de73a8b159'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 161,
#   u'scale': u'bta'},
#  {u'_id': ObjectId('55683839ea6387de73a8aac8'),
#   u'bregion': u'limbic system',
#   u'co-occ_count': 161,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('55683839ea6387de73a8aab4'),
#   u'bregion': u'subthalamic nucleus',
#   u'co-occ_count': 161,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('5568383cea6387de73a8de64'),
#   u'bregion': u'cerebral cortex',
#   u'co-occ_count': 161,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('5568383bea6387de73a8d36f'),
#   u'bregion': u'supramarginal gyrus',
#   u'co-occ_count': 160,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383bea6387de73a8d75a'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 160,
#   u'scale': u'toni'},
#  {u'_id': ObjectId('5568383bea6387de73a8d9a2'),
#   u'bregion': u'corpus callosum',
#   u'co-occ_count': 160,
#   u'scale': u'sib'},
#  {u'_id': ObjectId('5568383cea6387de73a8dcbc'),
#   u'bregion': u'parietal lobes',
#   u'co-occ_count': 160,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('55683839ea6387de73a8acc1'),
#   u'bregion': u'inferior frontal gyrus',
#   u'co-occ_count': 159,
#   u'scale': u'sib'},
#  {u'_id': ObjectId('5568383aea6387de73a8c0e1'),
#   u'bregion': u'temporal lobes',
#   u'co-occ_count': 159,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('5568383bea6387de73a8cf32'),
#   u'bregion': u'cingulate cortex',
#   u'co-occ_count': 159,
#   u'scale': u'cas'},
#  {u'_id': ObjectId('5568383aea6387de73a8afab'),
#   u'bregion': u'supramarginal gyrus',
#   u'co-occ_count': 158,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('55683839ea6387de73a8a646'),
#   u'bregion': u'temporal regions',
#   u'co-occ_count': 158,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('5568383aea6387de73a8bd5f'),
#   u'bregion': u'cingulate cortex',
#   u'co-occ_count': 158,
#   u'scale': u'bta'},
#  {u'_id': ObjectId('5568383aea6387de73a8b7f1'),
#   u'bregion': u'parietal lobes',
#   u'co-occ_count': 157,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b5a8'),
#   u'bregion': u'precentral gyrus',
#   u'co-occ_count': 157,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383aea6387de73a8b4a3'),
#   u'bregion': u'motor cortex',
#   u'co-occ_count': 157,
#   u'scale': u'abs'},
#  {u'_id': ObjectId('5568383aea6387de73a8b05c'),
#   u'bregion': u'cuneus',
#   u'co-occ_count': 157,
#   u'scale': u'sib'},
#  {u'_id': ObjectId('55683839ea6387de73a8ae8d'),
#   u'bregion': u'dentate gyrus',
#   u'co-occ_count': 157,
#   u'scale': u'pai'},
#  {u'_id': ObjectId('55683839ea6387de73a8a7c1'),
#   u'bregion': u'globus pallidus',
#   u'co-occ_count': 157,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383aea6387de73a8be86'),
#   u'bregion': u'angular gyrus',
#   u'co-occ_count': 157,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383aea6387de73a8c3f6'),
#   u'bregion': u'internal capsule',
#   u'co-occ_count': 157,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383bea6387de73a8c5d6'),
#   u'bregion': u'occipital regions',
#   u'co-occ_count': 157,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383bea6387de73a8c943'),
#   u'bregion': u'primary visual cortex',
#   u'co-occ_count': 157,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383aea6387de73a8b9ac'),
#   u'bregion': u'cingulate gyrus',
#   u'co-occ_count': 156,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('55683839ea6387de73a8a807'),
#   u'bregion': u'motor cortex',
#   u'co-occ_count': 156,
#   u'scale': u'dar'},
#  {u'_id': ObjectId('55683839ea6387de73a8a7ea'),
#   u'bregion': u'superior temporal gyrus',
#   u'co-occ_count': 156,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('5568383bea6387de73a8c7a6'),
#   u'bregion': u'caudate nucleus',
#   u'co-occ_count': 156,
#   u'scale': u'amen'},
#  {u'_id': ObjectId('5568383bea6387de73a8cc1e'),
#   u'bregion': u'postcentral gyrus',
#   u'co-occ_count': 156,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383bea6387de73a8d75e'),
#   u'bregion': u'posterior cingulate cortex',
#   u'co-occ_count': 154,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('5568383aea6387de73a8b589'),
#   u'bregion': u'basal forebrain',
#   u'co-occ_count': 153,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8c261'),
#   u'bregion': u'motor area',
#   u'co-occ_count': 153,
#   u'scale': u'pic'},
#  {u'_id': ObjectId('5568383bea6387de73a8cb59'),
#   u'bregion': u'frontal cortices',
#   u'co-occ_count': 153,
#   u'scale': u'pai'},
#  {u'_id': ObjectId('5568383bea6387de73a8d1d8'),
#   u'bregion': u'prefrontal cortex',
#   u'co-occ_count': 153,
#   u'scale': u'ysr'},
#  {u'_id': ObjectId('5568383bea6387de73a8d5aa'),
#   u'bregion': u'parietal lobe',
#   u'co-occ_count': 153,
#   u'scale': u'sib'},
#  {u'_id': ObjectId('5568383aea6387de73a8b300'),
#   u'bregion': u'subthalamic nucleus',
#   u'co-occ_count': 152,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383cea6387de73a8dccf'),
#   u'bregion': u'ventral striatum',
#   u'co-occ_count': 152,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('5568383aea6387de73a8b66e'),
#   u'bregion': u'hippocampal gyrus',
#   u'co-occ_count': 151,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('5568383aea6387de73a8b3d8'),
#   u'bregion': u'precuneus',
#   u'co-occ_count': 151,
#   u'scale': u'pic'},
#  {u'_id': ObjectId('55683839ea6387de73a8aa93'),
#   u'bregion': u'posterior cingulate gyrus',
#   u'co-occ_count': 151,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8c415'),
#   u'bregion': u'globus pallidus',
#   u'co-occ_count': 150,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383cea6387de73a8dd77'),
#   u'bregion': u'temporal lobe',
#   u'co-occ_count': 150,
#   u'scale': u'ils'},
#  {u'_id': ObjectId('55683839ea6387de73a8a775'),
#   u'bregion': u'anterior cingulate cortex',
#   u'co-occ_count': 149,
#   u'scale': u'pal'},
#  {u'_id': ObjectId('5568383aea6387de73a8c20b'),
#   u'bregion': u'premotor cortex',
#   u'co-occ_count': 149,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('5568383bea6387de73a8c631'),
#   u'bregion': u'thalamus',
#   u'co-occ_count': 149,
#   u'scale': u'bta'},
#  {u'_id': ObjectId('5568383bea6387de73a8d67b'),
#   u'bregion': u'entorhinal cortex',
#   u'co-occ_count': 149,
#   u'scale': u'pai'},
#  {u'_id': ObjectId('5568383cea6387de73a8ddad'),
#   u'bregion': u'primary motor cortex',
#   u'co-occ_count': 149,
#   u'scale': u'pai'},
#  {u'_id': ObjectId('5568383cea6387de73a8de42'),
#   u'bregion': u'frontal cortices',
#   u'co-occ_count': 149,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('5568383aea6387de73a8ba91'),
#   u'bregion': u'marginal gyrus',
#   u'co-occ_count': 148,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('55683839ea6387de73a8ac4b'),
#   u'bregion': u'somatosensory cortex',
#   u'co-occ_count': 148,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383aea6387de73a8bb67'),
#   u'bregion': u'amygdala',
#   u'co-occ_count': 148,
#   u'scale': u'mas'},
#  {u'_id': ObjectId('5568383aea6387de73a8bd08'),
#   u'bregion': u'temporal lobe',
#   u'co-occ_count': 148,
#   u'scale': u'aps'},
#  {u'_id': ObjectId('5568383bea6387de73a8c543'),
#   u'bregion': u'forebrain',
#   u'co-occ_count': 148,
#   u'scale': u'cri'},
#  {u'_id': ObjectId('5568383bea6387de73a8c86b'),
#   u'bregion': u'parietal cortex',
#   u'co-occ_count': 148,
#   u'scale': u'abs'},
#  {u'_id': ObjectId('5568383bea6387de73a8c969'),
#   u'bregion': u'parahippocampal gyrus',
#   u'co-occ_count': 148,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('5568383bea6387de73a8d2e6'),
#   u'bregion': u'parietal regions',
#   u'co-occ_count': 148,
#   u'scale': u'pic'},
#  {u'_id': ObjectId('5568383cea6387de73a8dc6f'),
#   u'bregion': u'striate cortex',
#   u'co-occ_count': 148,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8b743'),
#   u'bregion': u'hippocampus',
#   u'co-occ_count': 147,
#   u'scale': u'tea'},
#  {u'_id': ObjectId('55683839ea6387de73a8a399'),
#   u'bregion': u'medial frontal gyrus',
#   u'co-occ_count': 147,
#   u'scale': u'ssi'},
#  {u'_id': ObjectId('5568383bea6387de73a8c747'),
#   u'bregion': u'temporal cortex',
#   u'co-occ_count': 147,
#   u'scale': u'sib'},
#  {u'_id': ObjectId('5568383aea6387de73a8bb2f'),
#   u'bregion': u'corticotroph',
#   u'co-occ_count': 146,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8c478'),
#   u'bregion': u'supramarginal gyrus',
#   u'co-occ_count': 146,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383cea6387de73a8de0b'),
#   u'bregion': u'marginal gyrus',
#   u'co-occ_count': 146,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383aea6387de73a8b856'),
#   u'bregion': u'somatosensory cortex',
#   u'co-occ_count': 145,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383aea6387de73a8c027'),
#   u'bregion': u'hippocampal formation',
#   u'co-occ_count': 145,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383aea6387de73a8c17f'),
#   u'bregion': u'hypothalamus',
#   u'co-occ_count': 145,
#   u'scale': u'pic'},
#  {u'_id': ObjectId('5568383aea6387de73a8b53a'),
#   u'bregion': u'primary visual cortex',
#   u'co-occ_count': 144,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383aea6387de73a8b3b2'),
#   u'bregion': u'locus coeruleus',
#   u'co-occ_count': 144,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('5568383aea6387de73a8bd7d'),
#   u'bregion': u'medial frontal gyrus',
#   u'co-occ_count': 144,
#   u'scale': u'pat'},
#  {u'_id': ObjectId('5568383bea6387de73a8c53b'),
#   u'bregion': u'occipital cortex',
#   u'co-occ_count': 144,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('5568383bea6387de73a8c63a'),
#   u'bregion': u'occipital regions',
#   u'co-occ_count': 144,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383bea6387de73a8d4bb'),
#   u'bregion': u'temporal cortices',
#   u'co-occ_count': 144,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383bea6387de73a8d683'),
#   u'bregion': u'insular cortex',
#   u'co-occ_count': 144,
#   u'scale': u'tat'},
#  {u'_id': ObjectId('5568383aea6387de73a8ba4d'),
#   u'bregion': u'occipital regions',
#   u'co-occ_count': 143,
#   u'scale': u'da'},
#  {u'_id': ObjectId('5568383aea6387de73a8b2d0'),
#   u'bregion': u'corpus callosum',
#   u'co-occ_count': 143,
#   u'scale': u'aps'},
#  {u'_id': ObjectId('55683839ea6387de73a8aa21'),
#   u'bregion': u'caudate nucleus',
#   u'co-occ_count': 143,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('55683839ea6387de73a8a81c'),
#   u'bregion': u'parietal cortex',
#   u'co-occ_count': 143,
#   u'scale': u'pal'},
#  {u'_id': ObjectId('55683839ea6387de73a8a696'),
#   u'bregion': u'parietal cortex',
#   u'co-occ_count': 143,
#   u'scale': u'cas'},
#  {u'_id': ObjectId('55683839ea6387de73a8a4fe'),
#   u'bregion': u'neocortex',
#   u'co-occ_count': 143,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('5568383cea6387de73a8df3c'),
#   u'bregion': u'temporal regions',
#   u'co-occ_count': 143,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('5568383aea6387de73a8b26b'),
#   u'bregion': u'supplementary motor area',
#   u'co-occ_count': 142,
#   u'scale': u'pai'},
#  {u'_id': ObjectId('5568383aea6387de73a8bb86'),
#   u'bregion': u'supramarginal gyrus',
#   u'co-occ_count': 142,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383aea6387de73a8c476'),
#   u'bregion': u'parietal regions',
#   u'co-occ_count': 142,
#   u'scale': u'cri'},
#  {u'_id': ObjectId('5568383bea6387de73a8ceaf'),
#   u'bregion': u'frontal lobes',
#   u'co-occ_count': 142,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('5568383bea6387de73a8d32a'),
#   u'bregion': u'internal capsule',
#   u'co-occ_count': 142,
#   u'scale': u'nis'},
#  {u'_id': ObjectId('5568383aea6387de73a8b745'),
#   u'bregion': u'orbitofrontal cortex',
#   u'co-occ_count': 141,
#   u'scale': u'sib'},
#  {u'_id': ObjectId('55683839ea6387de73a8addc'),
#   u'bregion': u'midbrain',
#   u'co-occ_count': 141,
#   u'scale': u'cri'},
#  {u'_id': ObjectId('5568383aea6387de73a8c23d'),
#   u'bregion': u'temporal lobes',
#   u'co-occ_count': 141,
#   u'scale': u'oa'},
#  {u'_id': ObjectId('5568383bea6387de73a8cda9'),
#   u'bregion': u'anterior cingulate cortex',
#   u'co-occ_count': 141,
#   u'scale': u'dar'},
#  {u'_id': ObjectId('5568383bea6387de73a8cea0'),
#   u'bregion': u'anterior cingulate',
#   u'co-occ_count': 141,
#   u'scale': u'mas'},
#  {u'_id': ObjectId('5568383bea6387de73a8d72d'),
#   u'bregion': u'forebrain',
#   u'co-occ_count': 141,
#   u'scale': u'pai'},
#  {u'_id': ObjectId('5568383aea6387de73a8b5db'),
#   u'bregion': u'hippocampal formation',
#   u'co-occ_count': 140,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383aea6387de73a8afa5'),
#   u'bregion': u'occipital lobes',
#   u'co-occ_count': 140,
#   u'scale': u'ted'},
#  {u'_id': ObjectId('55683839ea6387de73a8a67a'),
#   u'bregion': u'cerebral hemisphere',
#   u'co-occ_count': 140,
#   u'scale': u'rl'},
#  {u'_id': ObjectId('5568383bea6387de73a8c502'),
#   u'bregion': u'anterior cingulate gyrus',
#   u'co-occ_count': 140,
#   u'scale': u'cat'},
#  {u'_id': ObjectId('5568383aea6387de73a8b568'),
#   u'bregion': u'parietal lobes',
#   u'co-occ_count': 139,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('55683839ea6387de73a8ae0f'),
#   u'bregion': u'insular cortex',
#   u'co-occ_count': 139,
#   u'scale': u'sis'},
#  {u'_id': ObjectId('5568383bea6387de73a8d3a3'),
#   u'bregion': u'frontal eye field',
#   u'co-occ_count': 139,
#   u'scale': u'da'},
#  ...]

# %%
# cursor_grouped = nwfeq2.aggregate(
#    [
#      { "$group" : { "_id" : "$co-occur_count", "nwfeq2": { "$push": "$scale" } } }
#    ]
# )
# list(cursor_grouped)

# %%
# vectorizer = TfidfVectorizer(stop_words="english", lowercase=False, encoding=u'utf-8')
# doc_vectors = vectorizer.fit_transform(content_vals)
# idf = vectorizer._tfidf.idf_
# idf_dic = dict(zip(vectorizer.get_feature_names(), idf))
# def format_brain(fname):
#     my_file = open(fname, "r")
#     read_file = my_file.read()
#     my_file.close()
#     return list(set(read_file.translate(string.maketrans("",""), string.punctuation).lower().split("\n")))

# def format_scale(fname):
#     my_file = open(fname, "r")
#     lines = list(set(my_file.read().split("\r")))
#     return [line.split(',')[0] for line in lines]

# bterms = format_brain("mesh_brain3.txt")
# sterms = format_scale("mmy_index.txt")

# %%
# nw2 = db.neuro_words2
# nw2.delete_many({"$where":"this.content.length < 100"})
# nw2.delete_many({"$where":"typeof(this.content) != 'string'"})
# thing = nw.find({},{"scales":1, "_id":0})
# list(thing)
