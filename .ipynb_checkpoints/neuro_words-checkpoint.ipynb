# %%
import sys, Quandl,nltk, csv, urllib2, codecs, simplejson, decimal
import numpy as np
from pprint import pprint as pp
from nltk.corpus import movie_reviews
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from textblob import TextBlob
from pymongo import MongoClient
import pandas as pd
from operator import itemgetter
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
client = MongoClient()
db = client.dsbc
nw = db.neuro_words

# q1 = {"content": 'Erratum in     J Neurosci. 2013 Jun 19;33(25):10582.'}
# q2 = {"content": 'Comment in     Psychopharmacology (Berl). 2014 Apr;231(8):1433-5.     Psychopharmacology (Berl). 2014 Apr;231(8):1433.' }
# q3 = {"content": 'Author information:  (1)Universitat de Barcelona, 08035 Barcelona, Espana.' }
# q4 = {"content": 'Erratum in     Psychon Bull Rev. 2013 Apr;20(2):400-1.' }
# q5 = {"content": 2011.0 }
# nw.delete_one(q1)
# nw.delete_one(q2)
# nw.delete_one(q3)
# nw.delete_one(q4)
# nw.delete_one(q5)

# contents = nw.find({},{"content":1, "_id":0})
# content_vals = [i['content'] for i in contents]
# len(content_vals)
list(nw.find({"$where":"this.content.length < 50"}))
# Out:
# [{u'_id': ObjectId('555e6c22fe6227222286398c'),
#   u'content': u'Comment in     Sleep. 2013 Sep;36(9):1273-4.',
#   u'pmid': u'PMCID: PMC3738039 PMID: 23997363  [PubMed - indexed for MEDLINE]',
#   u'title': u'Neural correlates of working memory performance in primary insomnia.'},
#  {u'_id': ObjectId('555e6c22fe6227222286395b'),
#   u'content': u'PMID: 24686570  [PubMed - indexed for MEDLINE]',
#   u'pmid': u'PMID: 24686570  [PubMed - indexed for MEDLINE]',
#   u'title': u"Contributions of children's linguistic and working memory proficiencies to their  judgments of grammaticality."},
#  {u'_id': ObjectId('555e6c22fe62272222863974'),
#   u'content': u'Erratum in     Front Neural Circuits. 2014;8:142.',
#   u'pmid': u'PMCID: PMC3986539 PMID: 24782714  [PubMed - indexed for MEDLINE]',
#   u'title': u'The role of prefrontal catecholamines in attention and working memory.'},
#  {u'_id': ObjectId('555e6c22fe6227222286399a'),
# ...

# %%
# vectorizer = TfidfVectorizer(stop_words="english", lowercase=False)
# doc_vectors = vectorizer.fit_transform(content_vals[87922:87925])
# idf = vectorizer._tfidf.idf_
# idf_dic = dict(zip(vectorizer.get_feature_names(), idf))
# pp(idf_dic)
pp(content_vals[87922])
# Out:
# 2011.0
